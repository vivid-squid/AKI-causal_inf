# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install captum
# Out:
# Collecting captum
#   Downloading captum-0.7.0-py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from captum) (3.7.1)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from captum) (1.26.4)
# Requirement already satisfied: torch>=1.6 in /usr/local/lib/python3.10/dist-packages (from captum) (2.3.1+cu121)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from captum) (4.66.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->captum) (3.15.4)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->captum) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->captum) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->captum) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->captum) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->captum) (2024.6.1)
# Collecting nvidia-cuda-nvrtc-cu12==12.1.105 (from torch>=1.6->captum)
#   Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.1.105 (from torch>=1.6->captum)
#   Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.1.105 (from torch>=1.6->captum)
#   Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==8.9.2.26 (from torch>=1.6->captum)
#   Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.1.3.1 (from torch>=1.6->captum)
#   Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.0.2.54 (from torch>=1.6->captum)
#   Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.2.106 (from torch>=1.6->captum)
#   Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.4.5.107 (from torch>=1.6->captum)
#   Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.1.0.106 (from torch>=1.6->captum)
#   Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu12==2.20.5 (from torch>=1.6->captum)
#   Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu12==12.1.105 (from torch>=1.6->captum)
#   Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Requirement already satisfied: triton==2.3.1 in /usr/local/lib/python3.10/dist-packages (from torch>=1.6->captum) (2.3.1)
# Collecting nvidia-nvjitlink-cu12 (from nvidia-cusolver-cu12==11.4.5.107->torch>=1.6->captum)
#   Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum) (1.2.1)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum) (4.53.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum) (24.1)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum) (3.1.2)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.10/dist-packages (from matplotlib->captum) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.10/dist-packages (from python-dateutil>=2.7->matplotlib->captum) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch>=1.6->captum) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch>=1.6->captum) (1.3.0)
# Downloading captum-0.7.0-py3-none-any.whl (1.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 36.7 MB/s eta 0:00:00
# Using cached nvidia_cublas_cu12-12.1.3.1-py3-none-manylinux1_x86_64.whl (410.6 MB)
# Using cached nvidia_cuda_cupti_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (14.1 MB)
# Using cached nvidia_cuda_nvrtc_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (23.7 MB)
# Using cached nvidia_cuda_runtime_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (823 kB)
# Using cached nvidia_cudnn_cu12-8.9.2.26-py3-none-manylinux1_x86_64.whl (731.7 MB)
# Using cached nvidia_cufft_cu12-11.0.2.54-py3-none-manylinux1_x86_64.whl (121.6 MB)
# Using cached nvidia_curand_cu12-10.3.2.106-py3-none-manylinux1_x86_64.whl (56.5 MB)
# Using cached nvidia_cusolver_cu12-11.4.5.107-py3-none-manylinux1_x86_64.whl (124.2 MB)
# Using cached nvidia_cusparse_cu12-12.1.0.106-py3-none-manylinux1_x86_64.whl (196.0 MB)
# Using cached nvidia_nccl_cu12-2.20.5-py3-none-manylinux2014_x86_64.whl (176.2 MB)
# Using cached nvidia_nvtx_cu12-12.1.105-py3-none-manylinux1_x86_64.whl (99 kB)
# Using cached nvidia_nvjitlink_cu12-12.6.20-py3-none-manylinux2014_x86_64.whl (19.7 MB)
# Installing collected packages: nvidia-nvtx-cu12, nvidia-nvjitlink-cu12, nvidia-nccl-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, captum
# Successfully installed captum-0.7.0 nvidia-cublas-cu12-12.1.3.1 nvidia-cuda-cupti-cu12-12.1.105 nvidia-cuda-nvrtc-cu12-12.1.105 nvidia-cuda-runtime-cu12-12.1.105 nvidia-cudnn-cu12-8.9.2.26 nvidia-cufft-cu12-11.0.2.54 nvidia-curand-cu12-10.3.2.106 nvidia-cusolver-cu12-11.4.5.107 nvidia-cusparse-cu12-12.1.0.106 nvidia-nccl-cu12-2.20.5 nvidia-nvjitlink-cu12-12.6.20 nvidia-nvtx-cu12-12.1.105

# %%
from datetime import datetime
print(datetime.now())
#data preprocessing
import pandas as pd
import numpy as np
from sklearn import preprocessing
from sklearn.model_selection import train_test_split
import collections
from collections import defaultdict
# NN
import torch
from torch.autograd import Variable
import torch.nn as nn
import torch.optim as optim
import torch.nn.functional as F
import time
import math
from sklearn.calibration import calibration_curve
from sklearn.metrics import roc_curve, precision_recall_curve, f1_score, roc_auc_score, auc, accuracy_score
from sklearn.metrics import average_precision_score
import sklearn.metrics as metrics
from sklearn.impute import SimpleImputer
import matplotlib.lines as mlines
import matplotlib.transforms as mtransforms
from matplotlib import pyplot as plt
import seaborn as sns
from captum.attr import IntegratedGradients

# the full files pathes are here
DATA_PATH_stages="/content/drive/MyDrive/Colab Notebooks/AKI/data/kdigo_stages_measured.csv"
DATA_PATH_labs = "/content/drive/MyDrive/Colab Notebooks/AKI/data/labs-kdigo_stages_measured.csv"
DATA_PATH_vitals = "/content/drive/MyDrive/Colab Notebooks/AKI/data/vitals-kdigo_stages_measured.csv"
DATA_PATH_vents = "/content/drive/MyDrive/Colab Notebooks/AKI/data/vents-vasopressor-sedatives-kdigo_stages_measured.csv"
DATA_PATH_detail="/content/drive/MyDrive/Colab Notebooks/AKI/data/icustay_detail-kdigo_stages_measured.csv"
SEPARATOR=";"
# Out:
# 2024-08-16 12:29:00.666106

# %%
IMPUTE_EACH_ID = False # imputation within each icustay_id with most common value
IMPUTE_COLUMN = True # imputation based on whole column

# %%
# Set parameter as constant

TESTING = False
TEST_SIZE = 0.05

SPLIT_SIZE = 0.2
MAX_DAYS = 31

#which classifier to use, only run one classifier at one time
CLASS1 = True   #AnyAKI
#CLASS2 = False    #ModerateSevereAKI
#CLASS3 = False    #SevereAKI
# ALL_STAGES = True # not binary label, each class separately 0,1,2,3

MAX_FEATURE_SET = True
#DIAGNOSIS = False

FIRST_TURN_POS = True # creating one label per one ICU stay id

# resampling  and imputing
TIME_SAMPLING = True
SAMPLING_INTERVAL = '6H'
RESAMPLE_LIMIT = 16 # 4 days*6h interval
MOST_COMMON = False #resampling with most common
# if MOST_COMMON is not applied,sampling with different strategies per kind of variable,
# numeric variables use mean value, categorical variables use max value

IMPUTE_METHOD = 'most_frequent'
FILL_VALUE = 0 #fill missing value and ragged part of 3d array

#Age constraints: adults
ADULTS_MIN_AGE = 18
ADULTS_MAX_AGE = -1

NORMALIZATION = 'min-max'

CAPPING_THRESHOLD_UPPER = 0.99
CAPPING_THRESHOLD_LOWER = 0.01

# How much time the prediction should occur (hours)
HOURS_AHEAD = 48

NORM_TYPE = 'min_max'

RANDOM = 42

#set changable info corresponding to each classifier as variables

min_set =  ["icustay_id", "charttime", "creat", "uo_rt_6hr", "uo_rt_12hr", "uo_rt_24hr", "aki_stage"]

max_set = ['icustay_id', 'charttime', 'aki_stage', 'hadm_id','aniongap_avg', 'bicarbonate_avg',
           'bun_avg','chloride_avg', 'creat', 'diasbp_mean', 'glucose_avg', 'heartrate_mean',
           'hematocrit_avg', 'hemoglobin_avg', 'potassium_avg', 'resprate_mean','sodium_avg', 'spo2_mean', 'sysbp_mean',
           'uo_rt_12hr', 'uo_rt_24hr','uo_rt_6hr', 'wbc_avg', 'sedative', 'vasopressor', 'vent', 'age', 'F','M',
           'asian', 'black', 'hispanic', 'native', 'other', 'unknown','white']

# LSTM
batch_size = 5

# naming model and plot
classifier_name = "None vs. Any AKI"    ###change every time #Moderate vs. Severe #None vs. Any #Others vs. Severe
plot_name = "adult_AnyAKI_LR"    ###change every time

# %%
# Some functions used later

# impute missing value in resampleing data with most common based on each id
def fast_mode(df, key_cols, value_col):
    """ Calculate a column mode, by group, ignoring null values.

    key_cols : list of str - Columns to groupby for calculation of mode.
    value_col : str - Column for which to calculate the mode.

    Return
    pandas.DataFrame
        One row for the mode of value_col per key_cols group. If ties, returns the one which is sorted first. """
    return (df.groupby(key_cols + [value_col]).size()
              .to_frame('counts').reset_index()
              .sort_values('counts', ascending=False)
              .drop_duplicates(subset=key_cols)).drop('counts',axis=1)


#get max shape of 3d array
def get_dimensions(array, level=0):
    yield level, len(array)
    try:
        for row in array:
            yield from get_dimensions(row, level + 1)
    except TypeError: #not an iterable
        pass

def get_max_shape(array):
    dimensions = defaultdict(int)
    for level, length in get_dimensions(array):
        dimensions[level] = max(dimensions[level], length)
    return [value for _, value in sorted(dimensions.items())]

#pad the ragged 3d array to rectangular shape based on max size
def iterate_nested_array(array, index=()):
    try:
        for idx, row in enumerate(array):
            yield from iterate_nested_array(row, (*index, idx))
    except TypeError: # final level
        yield (*index, slice(len(array))), array # think of the types

def pad(array, fill_value):
    dimensions = get_max_shape(array)
    result = np.full(dimensions, fill_value, dtype = np.float64)
    for index, value in iterate_nested_array(array):
        result[index] = value
    return result

def bin_total(y_true, y_prob, n_bins):
    bins = np.linspace(0., 1. + 1e-8, n_bins + 1)

    # In sklearn.calibration.calibration_curve,
    # the last value in the array is always 0.
    binids = np.digitize(y_prob, bins) - 1

    return np.bincount(binids, minlength=len(bins))

def missing_bin(bin_array):
    midpoint = " "
    if bin_array[0]==0:
        midpoint = "5%, "
    if bin_array[1]==0:
        midpoint = midpoint + "15%, "
    if bin_array[2]==0:
        midpoint = midpoint + "25%, "
    if bin_array[3]==0:
        midpoint = midpoint + "35%, "
    if bin_array[4]==0:
        midpoint = midpoint + "45%, "
    if bin_array[5]==0:
        midpoint = midpoint + "55%, "
    if bin_array[6]==0:
        midpoint = midpoint + "65%, "
    if bin_array[7]==0:
        midpoint = midpoint + "75%, "
    if bin_array[8]==0:
        midpoint = midpoint + "85%, "
    if bin_array[9]==0:
        midpoint = midpoint + "95%, "
    return "The missing bins have midpoint values of "+ str(midpoint)

# %%
print("read csv files")
#reading csv files
X = pd.read_csv(DATA_PATH_stages, sep= SEPARATOR)
X.drop(["aki_stage_creat", "aki_stage_uo"], axis = 1, inplace = True)
#remove totally empty rows
X = X.dropna(how = 'all', subset = ['creat','uo_rt_6hr','uo_rt_12hr','uo_rt_24hr','aki_stage'])
print("convert charttime to timestamp")
X['charttime'] = pd.to_datetime(X['charttime'])

#merge rows if they have exact timestamp within same icustay_id AL : it substitutes missing values with zero
#X = X.groupby(['icustay_id', 'charttime']).sum().reset_index(['icustay_id', 'charttime'])

dataset_detail = pd.read_csv(DATA_PATH_detail, sep= SEPARATOR)  #age constraint

# Rename the column 'admission_age' to 'age'
dataset_detail.rename(columns={'admission_age': 'age'}, inplace=True)

dataset_detail.drop(['dod', 'admittime','dischtime', 'los_hospital','ethnicity','hospital_expire_flag', 'hospstay_seq',
       'first_hosp_stay', 'intime', 'outtime', 'los_icu', 'icustay_seq','first_icu_stay'], axis = 1, inplace = True)
# Out:
# read csv files
# convert charttime to timestamp

# %%
dataset_labs = pd.read_csv(DATA_PATH_labs, sep= SEPARATOR) # 'bands lactate platelet ptt inr pt
dataset_labs.drop(['albumin_min', 'albumin_max','bilirubin_min', 'bilirubin_max','bands_min', 'bands_max',
                   'lactate_min', 'lactate_max','platelet_min', 'platelet_max','ptt_min', 'ptt_max',
                   'inr_min', 'inr_max', 'pt_min', 'pt_max'], axis = 1, inplace = True)
dataset_labs = dataset_labs.dropna(subset=['charttime'])
dataset_labs = dataset_labs.dropna(subset=dataset_labs.columns[4:], how='all')
dataset_labs['charttime'] = pd.to_datetime(dataset_labs['charttime'])
dataset_labs = dataset_labs.sort_values(by=['icustay_id', 'charttime'])

if  MAX_FEATURE_SET:
    dataset_vitals = pd.read_csv(DATA_PATH_vitals, sep= SEPARATOR)
    dataset_vents = pd.read_csv(DATA_PATH_vents , sep= SEPARATOR)
    #dataset_icd = pd.read_csv(DATA_PATH_icd, sep= SEPARATOR)
    dataset_vitals.drop(["heartrate_min", "heartrate_max","sysbp_min", "sysbp_max","diasbp_min", "diasbp_max",
                        'meanbp_min','meanbp_max', 'meanbp_mean','tempc_min', 'tempc_max', 'tempc_mean',
                        "resprate_min", "resprate_max", "spo2_min", "spo2_max", "glucose_min", "glucose_max"], axis = 1, inplace = True)
    print("convert charttime to timestamp")
    dataset_vitals['charttime'] = pd.to_datetime(dataset_vitals['charttime'])
    dataset_vents['charttime'] = pd.to_datetime(dataset_vents['charttime'])
    dataset_vitals = dataset_vitals.sort_values(by=['icustay_id', 'charttime'])
    dataset_vents = dataset_vents.sort_values(by=['icustay_id', 'charttime'])
    # AL drop those where all columns are nan (empty rows)
    dataset_vitals = dataset_vitals.dropna(subset=dataset_vitals.columns[4:], how='all')
# Out:
# convert charttime to timestamp

# %%
print(datetime.now())
# Labs file: instead of min and max their avg
counter = 0
col1 = 4
col2 = 5
null_l = [] # no null values in those that are different
changed = 0 # 4316 records changed to avg

while counter < 11:
    row = 0
# find where min and max are different and save their row indices
    while row < len(dataset_labs):
        a = dataset_labs.iloc[row,col1]
        b = dataset_labs.iloc[row,col2]
        if a==b or (np.isnan(a) and np.isnan(b)):
            pass
        elif a!=b:
            changed +=1
            avg = (a+b)/2
            dataset_labs.iloc[row,col1] = avg
            if (np.isnan(a) and ~np.isnan(b)) or (np.isnan(b) and ~np.isnan(a)):
                null_l.append(row)
        else:
            print(a)
            print(b)
        row +=1
    # delete the redundant column max, update counters
    dataset_labs.drop(dataset_labs.columns[col2], axis=1, inplace = True)
    counter = counter+1
    col1 = col1+1
    col2 = col2+1

dataset_labs.columns = ['subject_id','hadm_id', 'icustay_id', 'charttime', 'aniongap_avg', 'bicarbonate_avg',
                        'creatinine_avg', 'chloride_avg', 'glucose_avg', 'hematocrit_avg','hemoglobin_avg',
                        'potassium_avg', 'sodium_avg', 'bun_avg', 'wbc_avg']
if len(null_l)>0:
    print("null values encountered")
print(datetime.now())
# Out:
# 2024-08-16 12:29:48.124731
# 2024-08-16 12:37:14.043576

# %%
print("Merge creatinine and glucose.")
# merge creatinine from labs and set with labels
creat_l = dataset_labs[['icustay_id','charttime','creatinine_avg']].copy()
creat_l = creat_l.dropna(subset=['creatinine_avg'])
creat = X[['icustay_id','charttime', 'creat']].copy()
creat = creat.dropna(subset=['creat'])
creat_l = creat_l.rename(columns={"creatinine_avg": "creat"})
creat = pd.concat([creat, creat_l], ignore_index=True)
creat.drop_duplicates(inplace = True)
#delete old columns
dataset_labs.drop(["creatinine_avg"], axis = 1, inplace = True)
dataset_labs = dataset_labs.dropna(subset=dataset_labs.columns[4:], how='all')
X.drop(["creat"], axis = 1, inplace = True)
#merge new column
X = pd.merge(X, creat, on = ["icustay_id", "charttime"], sort = True, how= "outer", copy = False)

if MAX_FEATURE_SET:
    # merge glucose from vitals and labs
    glucose_v = dataset_vitals[['subject_id','hadm_id','icustay_id','charttime', 'glucose_mean']].copy()
    glucose_v = glucose_v.dropna(subset=['glucose_mean'])
    glucose = dataset_labs[['subject_id','hadm_id','icustay_id','charttime', 'glucose_avg']].copy()
    glucose = glucose.dropna(subset=['glucose_avg'])
    glucose_v = glucose_v.rename(columns={"glucose_mean": "glucose_avg"})
    glucose = pd.concat([glucose, glucose_v], ignore_index=True)
    glucose.drop_duplicates(inplace = True)
    #delete old columns
    dataset_labs.drop(["glucose_avg"], axis = 1, inplace = True)
    dataset_vitals.drop(["glucose_mean"], axis = 1, inplace = True)
    dataset_vitals = dataset_vitals.dropna(subset=dataset_vitals.columns[4:], how='all')
    #merge new column
    dataset_labs = pd.merge(dataset_labs, glucose, on = ['subject_id','hadm_id','icustay_id','charttime',], sort = True, how= "outer", copy = False)

dataset_labs = dataset_labs.sort_values(by=['icustay_id', 'charttime'], ignore_index = True)
X = X.sort_values(by=['icustay_id', 'charttime'], ignore_index = True)
# Out:
# Merge creatinine and glucose.

# %%
print("Merging labs, vitals and vents files")
if MAX_FEATURE_SET:
    X = pd.merge(X, dataset_labs, on = ["icustay_id", "charttime"], how= "outer", copy = False)
    X = pd.merge(X, dataset_vitals, on = ["icustay_id", "charttime","subject_id", "hadm_id"], how= "outer", copy = False)
    X = pd.merge(X, dataset_vents, on = ["icustay_id", "charttime"], how= "outer", copy = False)
    X.drop(["subject_id"], axis = 1, inplace = True)
# Out:
# Merging labs, vitals and vents files

# %%
print("start preprocessing time dependent data")
print("Removing patients under the min age")
dataset_detail = dataset_detail.loc[dataset_detail['age'] >= ADULTS_MIN_AGE]
adults_icustay_id_list = dataset_detail['icustay_id'].unique()
X = X[X.icustay_id.isin(adults_icustay_id_list)].sort_values(by=['icustay_id'], ignore_index = True)
X = X.sort_values(by=['icustay_id', 'charttime'], ignore_index = True)
adults_icustay_id_list = np.sort(adults_icustay_id_list)
# Out:
# start preprocessing time dependent data
# Removing patients under the min age

# %%
print("drop icustay_id with time span less than 48hrs")
def more_than_HOURS_ahead(adults_icustay_id_list, X):
    drop_list = []
    los_list = [] # calculating LOS ICU based on charttime
    long_stays_id = [] # LOS longer than MAX DAYS days
    last_charttime_list = []
    seq_length = X.groupby(['icustay_id'],as_index=False).size()
    id_count = 0
    first_row_index = 0

    while id_count < len(adults_icustay_id_list):
        icustay_id = adults_icustay_id_list[id_count]
        last_row_index = first_row_index + seq_length.iloc[id_count,1]-1
        first_time = X.iat[first_row_index, X.columns.get_loc('charttime')]
        last_time = X.iat[last_row_index, X.columns.get_loc('charttime')]
        los = round(float((last_time - first_time).total_seconds()/60/60/24),4) # in days
        if los < HOURS_AHEAD/24:
            drop_list.append(icustay_id)
        else:
            los_list.append(los)
            if los > MAX_DAYS:
                long_stays_id.append(icustay_id)
                last_charttime_list.append(last_time)
        # udpate for the next icustay_id
        first_row_index = last_row_index+1
        id_count +=1
    if len(long_stays_id) != len(last_charttime_list):
        print('ERROR')
    print("%d long stays" % len(long_stays_id))
    # drop all the rows with the saved icustay_id
    print("there are %d id-s shorter than 48 hours" % len(drop_list))
    X = X[~X.icustay_id.isin(drop_list)]
    id_list = X['icustay_id'].unique()
    X = X.sort_values(by=['icustay_id', 'charttime'], ignore_index = True)

    return id_list, X, long_stays_id,last_charttime_list

id_list, X, long_stays_id,last_charttime_list  = more_than_HOURS_ahead(adults_icustay_id_list, X)

long = pd.DataFrame()
long['icustay_id']  = long_stays_id
long['last_time']  = last_charttime_list
# Out:
# drop icustay_id with time span less than 48hrs
# 2936 long stays
# there are 5417 id-s shorter than 48 hours

# %%
# deleting rows that are not within MAX_DAYS (31) period
i = 0 # long df index
drop_long_time = []

while i < len(long_stays_id):
    j = 0
    all_rows = X.index[X['icustay_id'] == long.loc[i,'icustay_id']].tolist()
    while j < len(all_rows):
        time = X.iat[all_rows[j], X.columns.get_loc('charttime')]
        # if keep last MAX_DAYS
        if (long.loc[i,'last_time'] - time).total_seconds() > MAX_DAYS*24*60*60:
            drop_long_time.append(all_rows[j])
            j +=1
        else:
            break
    i +=1
X.drop(X.index[drop_long_time], inplace=True)

# checking for 48h min length again
id_list, X, long_stays_id,last_charttime_list  = more_than_HOURS_ahead(id_list, X)
dataset_detail = dataset_detail[dataset_detail.icustay_id.isin(id_list)].sort_values(by=['icustay_id'], ignore_index = True)
# Out:
# 0 long stays
# there are 1 id-s shorter than 48 hours

# %%
# For testing purpose, use small amount of data first
if TESTING:
    rest, id_list = train_test_split(id_list, test_size= TEST_SIZE, random_state=42)
    X = X[X.icustay_id.isin(id_list)].sort_values(by=['icustay_id'])
    dataset_detail = dataset_detail[dataset_detail.icustay_id.isin(id_list)].sort_values(by=['icustay_id'])

# %% [markdown]
# # Resampling , imputing

# %%
if (TIME_SAMPLING and MOST_COMMON):
    print("resampling: MOST_COMMON")
    # Resample the data using assigned interval,mode() for most common
    X = X.set_index('charttime').groupby('icustay_id').resample(SAMPLING_INTERVAL).mode().reset_index()
elif TIME_SAMPLING:
    print("resampling: MEAN & ZERO")
    # Sampling with different strategies per kind of variable
    label = ['aki_stage']
    skip = ['icustay_id', 'charttime', 'aki_stage']
    if MAX_FEATURE_SET:
        discrete_feat = ['sedative', 'vasopressor', 'vent', 'hadm_id']
        skip.extend(discrete_feat)
    # all features that are not in skip are numeric
    numeric_feat = list(X.columns.difference(skip))

    # Applying aggregation to features depending on their type
    X = X.set_index('charttime').groupby('icustay_id').resample(SAMPLING_INTERVAL)
    if MAX_FEATURE_SET:
        X_discrete = X[discrete_feat].max().fillna(FILL_VALUE).astype(np.int64)
    X_numeric = X[numeric_feat].mean()
    X_label = X['aki_stage'].max()
    print("Merging sampled features")
    try:
        X = pd.concat([X_numeric, X_discrete,X_label], axis=1).reset_index()
    except:
        X = pd.concat([X_numeric,X_label], axis=1).reset_index()
print(X.shape)
#Label forward fill
X['aki_stage'] = X['aki_stage'].ffill(limit=RESAMPLE_LIMIT)
# Out:
# resampling: MEAN & ZERO
# Merging sampled features
# (2028990, 26)

# %%
print("Imputation.")
# do imputation of label with zero if there are still missing values
X['aki_stage'] = X['aki_stage'].fillna(0)

# using most common within each icustay_id
if IMPUTE_EACH_ID:
    column_name = list(X.columns)
    column_name.remove(column_name[0])
    for feature in column_name:
        X.loc[X[feature].isnull(), feature] = X.icustay_id.map(fast_mode(X, ['icustay_id'], feature).set_index('icustay_id')[feature])

# imputation based on whole column
if IMPUTE_COLUMN:
    imp = SimpleImputer(missing_values=np.nan, strategy= IMPUTE_METHOD)
    cols = list(X.columns)
    cols = cols[2:23]
    X[cols]=imp.fit_transform(X[cols])

# If no imputation method selected or only impute each id, for the remaining nan impute direclty with FILL_VALUE
X = X.fillna(FILL_VALUE)
# Out:
# Imputation.

# %%
# more comfortable to review in this order
try:
    cols = ['icustay_id', 'charttime','aki_stage','hadm_id','aniongap_avg','bicarbonate_avg', 'bun_avg','chloride_avg',
            'creat','diasbp_mean', 'glucose_avg', 'heartrate_mean', 'hematocrit_avg','hemoglobin_avg',
            'potassium_avg', 'resprate_mean', 'sodium_avg','spo2_mean', 'sysbp_mean', 'uo_rt_12hr',
            'uo_rt_24hr', 'uo_rt_6hr','wbc_avg', 'sedative', 'vasopressor', 'vent' ]
    X = X[cols]
    print("success")
except:
    try:
        cols = ['icustay_id', 'charttime','aki_stage','creat','uo_rt_12hr', 'uo_rt_24hr', 'uo_rt_6hr']
        X = X[cols]
    except:
        print("error")
# Out:
# success

# %%
print("binarise labels")
if ALL_STAGES:
    pass
elif CLASS1:
    X.loc[X['aki_stage'] > 1, 'aki_stage'] = 1
elif CLASS2:
    X.loc[X['aki_stage'] < 2, 'aki_stage'] = 0
    X.loc[X['aki_stage'] > 1, 'aki_stage'] = 1
elif CLASS3:
    X.loc[X['aki_stage'] < 3, 'aki_stage'] = 0
    X.loc[X['aki_stage'] > 2, 'aki_stage'] = 1
# Out:
# binarise labels

# %%
print(X.columns)
# Out:
# Index(['icustay_id', 'charttime', 'aki_stage', 'hadm_id', 'aniongap_avg',
#        'bicarbonate_avg', 'bun_avg', 'chloride_avg', 'creat', 'diasbp_mean',
#        'glucose_avg', 'heartrate_mean', 'hematocrit_avg', 'hemoglobin_avg',
#        'potassium_avg', 'resprate_mean', 'sodium_avg', 'spo2_mean',
#        'sysbp_mean', 'uo_rt_12hr', 'uo_rt_24hr', 'uo_rt_6hr', 'wbc_avg',
#        'sedative', 'vasopressor', 'vent'],
#       dtype='object')

# %% [markdown]
# # SHIFTING labels

# %%
#print("Shifting the labels 48 h") # by 8 position : 6h sampling*8=48h and ffil 8 newly empty ones
X['aki_stage'] = X.groupby('icustay_id')['aki_stage'].shift(-(HOURS_AHEAD // int(SAMPLING_INTERVAL[:-1])))
X = X.dropna(subset=['aki_stage'])
X['icustay_id'].nunique()
# Out:
# 47250

# %%
# Create one label per icustay_id - first turn positive approach
if FIRST_TURN_POS:
    X = X.sort_values(by=['icustay_id', 'charttime'], ignore_index=True)
    id_list.sort()
    last_charttime_list = []
    index_list = []
    label_list = []
    filtered_id_list = []

    first_row_index = 0
    id_count = 0
    seq_length = X.groupby(['icustay_id']).size().reset_index(name='count')

    for ID in id_list:
        if id_count >= len(seq_length):
            break

        last_row_index = first_row_index + seq_length.iloc[id_count]['count'] - 1
        a = X.loc[X['icustay_id'] == ID].aki_stage
        if 1 not in a.values:
            label_list.append(0)
            last_charttime_list.append(X.iat[last_row_index, X.columns.get_loc('charttime')])
            index_list.append(last_row_index)
            filtered_id_list.append(ID)
        else:
            row = first_row_index
            while row <= last_row_index:
                if X.iat[row, X.columns.get_loc('aki_stage')] == 1:
                    label_list.append(1)
                    last_charttime_list.append(X.iat[row, X.columns.get_loc('charttime')])
                    index_list.append(row)
                    filtered_id_list.append(ID)
                    break
                row += 1
        first_row_index = last_row_index + 1
        id_count += 1

    # Debugging statements
    print(f"Length of filtered_id_list: {len(filtered_id_list)}")
    print(f"Length of last_charttime_list: {len(last_charttime_list)}")
    print(f"Length of label_list: {len(label_list)}")

    if len(filtered_id_list) == len(last_charttime_list) == len(label_list):
        X = X.drop(['aki_stage'], axis=1)
        Thresholds = pd.DataFrame({'icustay_id': filtered_id_list, 'charttime': last_charttime_list, 'final_label': label_list})
        X = (Thresholds.merge(X, on='icustay_id', how='left', suffixes=('_x', '')).query("charttime_x >= charttime").reindex(columns=X.columns))
        print(X.shape)
        print(X['icustay_id'].nunique())
    else:
        print("Error: The lengths of the lists do not match.")

# Assuming label_register code follows the successful creation of Thresholds
if len(filtered_id_list) == len(label_list):
    label_register = pd.DataFrame()
    label_register['icustay_id'] = filtered_id_list
    label_register['label'] = label_list
else:
    print("Error: Unable to create label_register due to length mismatch.")
# Out:
# Length of filtered_id_list: 35781
# Length of last_charttime_list: 35781
# Length of label_list: 35781
# (577930, 25)
# 18054

# %%
print(X.columns)
# Out:
# Index(['icustay_id', 'charttime', 'hadm_id', 'aniongap_avg', 'bicarbonate_avg',
#        'bun_avg', 'chloride_avg', 'creat', 'diasbp_mean', 'glucose_avg',
#        'heartrate_mean', 'hematocrit_avg', 'hemoglobin_avg', 'potassium_avg',
#        'resprate_mean', 'sodium_avg', 'spo2_mean', 'sysbp_mean', 'uo_rt_12hr',
#        'uo_rt_24hr', 'uo_rt_6hr', 'wbc_avg', 'sedative', 'vasopressor',
#        'vent'],
#       dtype='object')

# %% [markdown]
# # Add categorical features (details)

# %%
print("start preprocessing not time dependent data")
if MAX_FEATURE_SET:
    #extract datasets based on id_list
    dataset_detail = dataset_detail.loc[dataset_detail['icustay_id'].isin(id_list)]
    #sort by ascending order
    dataset_detail = dataset_detail.sort_values(by=['icustay_id'])
    subject_id = dataset_detail["subject_id"].unique()
    #transfrom categorical data to binary form
    dataset_detail = dataset_detail.join(pd.get_dummies(dataset_detail.pop('gender')))
    dataset_detail = dataset_detail.join(pd.get_dummies(dataset_detail.pop("ethnicity_grouped")))
    #dataset_detail = dataset_detail.join(pd.get_dummies(dataset_detail.pop('admission_type')))
    dataset_detail = dataset_detail.drop(['subject_id', 'hadm_id'], axis=1)
    X =  pd.merge(X, dataset_detail, on = ["icustay_id"], how= "left", copy = False)
    numeric_feat.append('age')
# Out:
# start preprocessing not time dependent data

# %%
feature_names =['Anion gap', 'Bicarbonate', 'Blood Urea Nitrogen', 'Chloride', 'Creatinine', 'Diastolic BP', 'Glucose', 'Heart rate',
            'Hematocrit', 'Hemoglobin', 'Potassium', 'Respiratory rate', 'Sodium', 'Oxygen saturation', 'Systolic BP', 'Urine output 12h', 'Urine output 24h', 'Urine output 6h',
            'White cell count', 'Sedative', 'Vasopressor', 'Ventilation', 'Age', 'Female gender', 'Male gender', 'Asian ethnicity', 'Black ethnicity', 'Hispanic ethnicity', 'Native american',
            'Other ethnicity', 'Ethnicity unknown', 'White ethnicity']

# %%
X
# Out:
#         icustay_id           charttime   hadm_id  aniongap_avg  \
# 0           200001 2181-11-18 06:00:00  152234.0          11.0
# 1           200001 2181-11-18 12:00:00       0.0          13.0
# 2           200001 2181-11-18 18:00:00       0.0          13.0
# 3           200001 2181-11-19 00:00:00       0.0          13.0
# 4           200001 2181-11-19 06:00:00  152234.0          14.0
# ...            ...                 ...       ...           ...
# 577925      299818 2163-06-29 00:00:00  157997.0          10.0
# 577926      299818 2163-06-29 06:00:00  157997.0          13.0
# 577927      299818 2163-06-29 12:00:00  157997.0          13.0
# 577928      299818 2163-06-29 18:00:00  157997.0          13.0
# 577929      299818 2163-06-30 00:00:00  157997.0          10.0
#
#         bicarbonate_avg  bun_avg  chloride_avg  creat  diasbp_mean  \
# 0                  30.0     42.0         107.0    2.5    59.000000
# 1                  25.0     15.0         104.0    0.7    59.000000
# 2                  25.0     15.0         104.0    0.7    59.000000
# 3                  25.0     15.0         104.0    0.7    59.000000
# 4                  27.0     46.0         105.0    2.7    59.000000
# ...                 ...      ...           ...    ...          ...
# 577925             26.0     18.0         109.0    1.0    47.500000
# 577926             25.0     15.0         104.0    0.7    51.200000
# 577927             25.0     15.0         106.0    0.7    48.333333
# 577928             25.0     15.0         104.0    0.7    55.000000
# 577929             30.0     19.0         106.0    0.9    50.500000
#
#         glucose_avg  ...        age     F      M  asian  black  hispanic  \
# 0         90.000000  ...  61.071279  True  False   True  False     False
# 1        111.000000  ...  61.071279  True  False   True  False     False
# 2        111.000000  ...  61.071279  True  False   True  False     False
# 3        111.000000  ...  61.071279  True  False   True  False     False
# 4         74.000000  ...  61.071279  True  False   True  False     False
# ...             ...  ...        ...   ...    ...    ...    ...       ...
# 577925   118.666667  ...  72.405247  True  False  False  False     False
# 577926   122.000000  ...  72.405247  True  False  False  False     False
# 577927   118.000000  ...  72.405247  True  False  False  False     False
# 577928   160.000000  ...  72.405247  True  False  False  False     False
# 577929    87.000000  ...  72.405247  True  False  False  False     False
#
#         native  other  unknown  white
# 0        False  False    False  False
# 1        False  False    False  False
# 2        False  False    False  False
# 3        False  False    False  False
# 4        False  False    False  False
# ...        ...    ...      ...    ...
# 577925   False  False    False   True
# 577926   False  False    False   True
# 577927   False  False    False   True
# 577928   False  False    False   True
# 577929   False  False    False   True
#
# [577930 rows x 35 columns]

# %%
print(X.columns)
# Out:
# Index(['icustay_id', 'charttime', 'hadm_id', 'aniongap_avg', 'bicarbonate_avg',
#        'bun_avg', 'chloride_avg', 'creat', 'diasbp_mean', 'glucose_avg',
#        'heartrate_mean', 'hematocrit_avg', 'hemoglobin_avg', 'potassium_avg',
#        'resprate_mean', 'sodium_avg', 'spo2_mean', 'sysbp_mean', 'uo_rt_12hr',
#        'uo_rt_24hr', 'uo_rt_6hr', 'wbc_avg', 'sedative', 'vasopressor', 'vent',
#        'age', 'F', 'M', 'asian', 'black', 'hispanic', 'native', 'other',
#        'unknown', 'white'],
#       dtype='object')

# %%
X.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_init-ord.csv', index=False)
# X.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_init.csv', index=False)

# %% [markdown]
# #  Cap features between 0.01 / 0.99 quantile and normalisation

# %%
# Replace values in the 'age' column greater than 89 with 90
X['age'] = X['age'].apply(lambda x: 90.0 if x > 89 else x)

# Check the number of occurrences of the value 90
num_ninety_values = (X['age'] == 90.0).sum()

# Alternatively, using value_counts:
# num_ninety_values = X['age'].value_counts().get(90.0, 0)

# Print the result
print(f"Number of values equal to 90 in the 'age' column: {num_ninety_values}")

# Verify the changes
print(X['age'].unique())
# Out:
# Number of values equal to 90 in the 'age' column: 22748
# [61.07127869 48.29627051 54.07230806 ... 80.46649905 70.30398583
#  72.40524744]

# %%
# X.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_crt-age-ord.csv', index=False)
X.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_crt-age_flat.csv', index=False)

# %%
# X = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_crt-age-ord.csv')
X = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_crt-age_flat.csv')

# %%
# Define the features that need capping and normalization, including 'age'
numeric_features = [
    'aniongap_avg', 'bicarbonate_avg', 'bun_avg', 'chloride_avg', 'creat',
    'diasbp_mean', 'glucose_avg', 'heartrate_mean', 'hematocrit_avg',
    'hemoglobin_avg', 'potassium_avg', 'resprate_mean', 'sodium_avg',
    'spo2_mean', 'sysbp_mean', 'uo_rt_12hr', 'uo_rt_24hr', 'uo_rt_6hr',
    'wbc_avg', 'age'
]

# Convert binary features to 0/1 (not included in capping or normalization)
binary_features = [
    'F', 'M', 'asian', 'black', 'hispanic', 'native', 'other', 'unknown',
    'white', 'sedative', 'vasopressor', 'vent'
]
X[binary_features] = X[binary_features].astype(int)

# Function to cap numeric data
def cap_data(df):
    print(f"Capping between the {CAPPING_THRESHOLD_LOWER} and {CAPPING_THRESHOLD_UPPER} quantile")

    # Apply the clipping to numeric features only
    df[numeric_features] = df[numeric_features].clip(
        df[numeric_features].quantile(CAPPING_THRESHOLD_LOWER),
        df[numeric_features].quantile(CAPPING_THRESHOLD_UPPER),
        axis=1
    )
    return df

# Function to normalize numeric data
def normalise_data(df):
    print(f"Normalizing in [0,1] with {NORMALIZATION} normalization")

    # Apply normalization to numeric features only
    df[numeric_features] = (df[numeric_features] - df[numeric_features].min()) / \
                            (df[numeric_features].max() - df[numeric_features].min())
    return df

# Print the first few rows of the aki_stage and sedatives columns before applying capping and normalization
print("Before capping and normalization:")
print(X['aki_stage'].head())
print(X['sedative'].head())

# Apply capping
X = cap_data(X)

# Print the first few rows of the aki_stage and sedatives columns after capping to check if it was modified
print("After capping:")
print(X['aki_stage'].head())
print(X['sedative'].head())

# Apply normalization
X = normalise_data(X)

# Print the first few rows of the aki_stage and sedatives columns after normalization to check if it was modified
print("After normalization:")
print(X['aki_stage'].head())
print(X['sedative'].head())

# %%
X = X.sort_values(by=['icustay_id', 'charttime'])
seq_lengths = X.groupby(['icustay_id'],as_index=False).size().sort_values(by = ['size'],ascending=False)
sequence_length = seq_lengths.max() # the longest sequence per icustay-id
print(sequence_length)
# Out:
# icustay_id    299818
# size             227
# dtype: int64

# %%
#AL re-write as try except to make it work as hadm_id is not used if only one csv file is used and none are merged
try:
    X.drop(['hadm_id'], axis=1, inplace = True)
except:
    pass

# %%
features = X.shape[1]-3
print(features)
# Out:
# 32

# %%
print("divide dataset into train, test and validation sets")
id_train, id_test_val = train_test_split(id_list, test_size = SPLIT_SIZE, random_state = 42) # train set is 80%)
print("train is %d" % len(id_train))
# remaining 20% split in halves as test and validation 10% and 10%
id_valid, id_test = train_test_split(id_test_val, test_size = 0.5, random_state = 42) # test 10% valid 10%
print("val and test are %d" %len(id_test))
# Out:
# divide dataset into train, test and validation sets
# train is 37868
# val and test are 4734

# %%
train = X[X.icustay_id.isin(id_train)].sort_values(by=['icustay_id'])
test = X[X.icustay_id.isin(id_test)].sort_values(by=['icustay_id'], ignore_index = True)
validation = X[X.icustay_id.isin(id_valid)].sort_values(by=['icustay_id'])

test = test.sort_values(by=['icustay_id', 'charttime'], ignore_index = True)
train = train.sort_values(by=['icustay_id', 'charttime'], ignore_index = True)
validation = validation.sort_values(by=['icustay_id', 'charttime'], ignore_index = True)

# %%
test.shape
# Out:
# (58036, 35)

# %%
test['icustay_id'].nunique()
# Out:
# 1793

# %%
train['icustay_id'].nunique()
# Out:
# 14490

# %%
validation['icustay_id'].nunique()
# Out:
# 1771

# %%
test_seq = test.groupby(['icustay_id'],as_index=False).size()

# %% [markdown]
# # Generate the test set before onset

# %%
# Check if 'aki_stage' exists in the test DataFrame
if 'aki_stage' not in test.columns:
    raise KeyError("'aki_stage' column not found in the test DataFrame")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-41-7b833b8ee5cd> in <cell line: 2>()
#       1 # Check if 'aki_stage' exists in the test DataFrame
#       2 if 'aki_stage' not in test.columns:
# ----> 3     raise KeyError("'aki_stage' column not found in the test DataFrame")
#
# KeyError: "'aki_stage' column not found in the test DataFrame"

# %%
Z = test.copy(deep = True)
test = test.sort_values(by=['icustay_id', 'charttime'], ignore_index = True)
id_test.sort()


index_list = []
label_list = []

first_row_index = 0
id_count = 0
seq_length = Z.groupby(['icustay_id'], as_index=False).size()

# Filter id_test to only include IDs present in Z (i.e., in seq_length)
id_test_filtered = [ID for ID in id_test if ID in seq_length['icustay_id'].values]

# Loop through the filtered id_test
for ID in id_test_filtered:
    # Get the number of rows for the current ID in Z
    last_row_index = first_row_index + seq_length[seq_length['icustay_id'] == ID].iloc[0, 1] - 1

    # Extract the aki_stage column for the current ID
    aki_stages = Z.loc[Z['icustay_id'] == ID, 'aki_stage'].values

    # Default to the last index with the maximum AKI stage (3), if present
    if 3 in aki_stages:
        label_list.append(3)
        index_list.append(np.argmax(aki_stages == 3) + first_row_index)
    elif 2 in aki_stages:
        label_list.append(2)
        index_list.append(np.argmax(aki_stages == 2) + first_row_index)
    elif 1 in aki_stages:
        label_list.append(1)
        index_list.append(np.argmax(aki_stages == 1) + first_row_index)
    else:
        label_list.append(0)
        index_list.append(last_row_index)

    # Update the first_row_index for the next iteration
    first_row_index = last_row_index + 1
    id_count += 1

# Now index_list and label_list contain the results of the processed IDs
print("Processed index_list:", index_list)
print("Processed label_list:", label_list)

print(f"Length of id_test: {len(id_test)}")
print(f"Length of seq_length: {len(seq_length)}")

# Get the number of elements in index_list
num_elements_index_list = len(index_list)

# Get the number of elements in label_list
num_elements_label_list = len(label_list)

# Print the results
print(f"Number of elements in index_list: {num_elements_index_list}")
print(f"Number of elements in label_list: {num_elements_label_list}")

# %%
Z = test.copy(deep = True)
test = test.sort_values(by=['icustay_id', 'charttime'], ignore_index = True)
id_test.sort()
seq_length = Z.groupby(['icustay_id'],as_index=False).size()
#last_charttime_list= []

# Step 1: Filter id_test to keep only IDs that exist in seq_length
id_test_filtered = [ID for ID in id_test if ID in seq_length['icustay_id'].values]

# Step 2: Reinitialize the variables
index_list = []
label_list = []

first_row_index = 0
id_count = 0

# Step 3: Run the loop with the filtered id_test
for ID in id_test_filtered:
    last_row_index = first_row_index + seq_length.iloc[id_count, 1] - 1
    a = Z.loc[Z['icustay_id'] == ID].aki_stage

    if 1 not in a.values:
        label_list.append(0)
        index_list.append(last_row_index)
    elif 1 in a.values:
        row = first_row_index
        while row != last_row_index + 1:
            if Z.iat[row, Z.columns.get_loc('aki_stage')] == 0:
                row += 1
            elif Z.iat[row, Z.columns.get_loc('aki_stage')] == 1:
                index_list.append(row)
                break

    first_row_index = last_row_index + 1
    id_count += 1

# Proceed with the rest of your analysis
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-139-b55833681959> in <cell line: 18>()
#      18 for ID in id_test_filtered:
#      19     last_row_index = first_row_index + seq_length.iloc[id_count, 1] - 1
# ---> 20     a = Z.loc[Z['icustay_id'] == ID].aki_stage
#      21
#      22     if 1 not in a.values:
#
# /usr/local/lib/python3.10/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    6202         ):
#    6203             return self[name]
# -> 6204         return object.__getattribute__(self, name)
#    6205
#    6206     @final
#
# AttributeError: 'DataFrame' object has no attribute 'aki_stage'

# %%
# Merge label_register with test data to get the labels
Z = test.merge(label_register, on='icustay_id', how='left')

# Sort test data if needed
Z = Z.sort_values(by=['icustay_id', 'charttime'], ignore_index=True)
id_test.sort()
seq_length = Z.groupby(['icustay_id'], as_index=False).size()

# Filter id_test to keep only IDs that exist in seq_length
id_test_filtered = [ID for ID in id_test if ID in seq_length['icustay_id'].values]

# Reset label_list and index_list
label_list = []
index_list = []

# Ensure the first_row_index is reset before the loop
first_row_index = 0
id_count = 0

for ID in filtered_id_list:
    # Ensure the ID exists in seq_length before attempting to access it
    filtered_seq_length = seq_length[seq_length['icustay_id'] == ID]

    if filtered_seq_length.empty:
        print(f"Warning: ID {ID} not found in seq_length.")
        continue  # Skip this ID if it's not found

    last_row_index = first_row_index + filtered_seq_length.iloc[0, 1] - 1

    # Use the 'label' from the label_register directly since 'aki_stage' is dropped
    label = label_register.loc[label_register['icustay_id'] == ID, 'label'].values[0]
    label_list.append(label)
    index_list.append(last_row_index if label == 0 else first_row_index)

    first_row_index = last_row_index + 1
    id_count += 1

# After the loop, check the lengths again
print(f"New Length of filtered_id_list: {len(filtered_id_list)}")
print(f"New Length of label_list: {len(label_list)}")

# Check if they now match
if len(filtered_id_list) != len(label_list):
    print("Error: Lengths still do not match.")
else:
    print("Lengths match. Proceeding with further processing.")
# Out:
# Streaming output truncated to the last 5000 lines.
# Warning: ID 285235 not found in seq_length.
# Warning: ID 285236 not found in seq_length.
# Warning: ID 285237 not found in seq_length.
# Warning: ID 285241 not found in seq_length.
# Warning: ID 285244 not found in seq_length.
# Warning: ID 285247 not found in seq_length.
# Warning: ID 285250 not found in seq_length.
# Warning: ID 285252 not found in seq_length.
# Warning: ID 285254 not found in seq_length.
# Warning: ID 285255 not found in seq_length.
# Warning: ID 285257 not found in seq_length.
# Warning: ID 285259 not found in seq_length.
# Warning: ID 285262 not found in seq_length.
# Warning: ID 285265 not found in seq_length.
# Warning: ID 285270 not found in seq_length.
# Warning: ID 285272 not found in seq_length.
# Warning: ID 285274 not found in seq_length.
# Warning: ID 285278 not found in seq_length.
# Warning: ID 285279 not found in seq_length.
# Warning: ID 285283 not found in seq_length.
# Warning: ID 285287 not found in seq_length.
# Warning: ID 285289 not found in seq_length.
# Warning: ID 285290 not found in seq_length.
# Warning: ID 285291 not found in seq_length.
# Warning: ID 285300 not found in seq_length.
# Warning: ID 285301 not found in seq_length.
# Warning: ID 285302 not found in seq_length.
# Warning: ID 285303 not found in seq_length.
# Warning: ID 285305 not found in seq_length.
# Warning: ID 285308 not found in seq_length.
# Warning: ID 285309 not found in seq_length.
# Warning: ID 285319 not found in seq_length.
# Warning: ID 285321 not found in seq_length.
# Warning: ID 285325 not found in seq_length.
# Warning: ID 285326 not found in seq_length.
# Warning: ID 285328 not found in seq_length.
# Warning: ID 285330 not found in seq_length.
# Warning: ID 285335 not found in seq_length.
# Warning: ID 285340 not found in seq_length.
# Warning: ID 285348 not found in seq_length.
# Warning: ID 285350 not found in seq_length.
# Warning: ID 285353 not found in seq_length.
# Warning: ID 285356 not found in seq_length.
# Warning: ID 285357 not found in seq_length.
# Warning: ID 285359 not found in seq_length.
# Warning: ID 285362 not found in seq_length.
# Warning: ID 285365 not found in seq_length.
# Warning: ID 285367 not found in seq_length.
# Warning: ID 285368 not found in seq_length.
# Warning: ID 285369 not found in seq_length.
# Warning: ID 285373 not found in seq_length.
# Warning: ID 285376 not found in seq_length.
# Warning: ID 285378 not found in seq_length.
# Warning: ID 285380 not found in seq_length.
# Warning: ID 285381 not found in seq_length.
# Warning: ID 285383 not found in seq_length.
# Warning: ID 285384 not found in seq_length.
# Warning: ID 285387 not found in seq_length.
# Warning: ID 285389 not found in seq_length.
# Warning: ID 285394 not found in seq_length.
# Warning: ID 285396 not found in seq_length.
# Warning: ID 285397 not found in seq_length.
# Warning: ID 285400 not found in seq_length.
# Warning: ID 285406 not found in seq_length.
# Warning: ID 285407 not found in seq_length.
# Warning: ID 285409 not found in seq_length.
# Warning: ID 285416 not found in seq_length.
# Warning: ID 285421 not found in seq_length.
# Warning: ID 285422 not found in seq_length.
# Warning: ID 285427 not found in seq_length.
# Warning: ID 285433 not found in seq_length.
# Warning: ID 285435 not found in seq_length.
# Warning: ID 285442 not found in seq_length.
# Warning: ID 285444 not found in seq_length.
# Warning: ID 285446 not found in seq_length.
# Warning: ID 285457 not found in seq_length.
# Warning: ID 285461 not found in seq_length.
# Warning: ID 285462 not found in seq_length.
# Warning: ID 285463 not found in seq_length.
# Warning: ID 285466 not found in seq_length.
# Warning: ID 285471 not found in seq_length.
# Warning: ID 285475 not found in seq_length.
# Warning: ID 285476 not found in seq_length.
# Warning: ID 285480 not found in seq_length.
# Warning: ID 285482 not found in seq_length.
# Warning: ID 285483 not found in seq_length.
# Warning: ID 285484 not found in seq_length.
# Warning: ID 285485 not found in seq_length.
# Warning: ID 285487 not found in seq_length.
# Warning: ID 285489 not found in seq_length.
# Warning: ID 285490 not found in seq_length.
# Warning: ID 285494 not found in seq_length.
# Warning: ID 285497 not found in seq_length.
# Warning: ID 285498 not found in seq_length.
# Warning: ID 285507 not found in seq_length.
# Warning: ID 285508 not found in seq_length.
# Warning: ID 285509 not found in seq_length.
# Warning: ID 285514 not found in seq_length.
# Warning: ID 285518 not found in seq_length.
# Warning: ID 285522 not found in seq_length.
# Warning: ID 285525 not found in seq_length.
# Warning: ID 285526 not found in seq_length.
# Warning: ID 285528 not found in seq_length.
# Warning: ID 285532 not found in seq_length.
# Warning: ID 285534 not found in seq_length.
# Warning: ID 285536 not found in seq_length.
# Warning: ID 285537 not found in seq_length.
# Warning: ID 285541 not found in seq_length.
# Warning: ID 285542 not found in seq_length.
# Warning: ID 285543 not found in seq_length.
# Warning: ID 285545 not found in seq_length.
# Warning: ID 285546 not found in seq_length.
# Warning: ID 285548 not found in seq_length.
# Warning: ID 285549 not found in seq_length.
# Warning: ID 285552 not found in seq_length.
# Warning: ID 285555 not found in seq_length.
# Warning: ID 285556 not found in seq_length.
# Warning: ID 285566 not found in seq_length.
# Warning: ID 285567 not found in seq_length.
# Warning: ID 285569 not found in seq_length.
# Warning: ID 285572 not found in seq_length.
# Warning: ID 285577 not found in seq_length.
# Warning: ID 285578 not found in seq_length.
# Warning: ID 285579 not found in seq_length.
# Warning: ID 285580 not found in seq_length.
# Warning: ID 285583 not found in seq_length.
# Warning: ID 285587 not found in seq_length.
# Warning: ID 285589 not found in seq_length.
# Warning: ID 285590 not found in seq_length.
# Warning: ID 285596 not found in seq_length.
# Warning: ID 285599 not found in seq_length.
# Warning: ID 285600 not found in seq_length.
# Warning: ID 285603 not found in seq_length.
# Warning: ID 285604 not found in seq_length.
# Warning: ID 285608 not found in seq_length.
# Warning: ID 285610 not found in seq_length.
# Warning: ID 285611 not found in seq_length.
# Warning: ID 285618 not found in seq_length.
# Warning: ID 285620 not found in seq_length.
# Warning: ID 285621 not found in seq_length.
# Warning: ID 285630 not found in seq_length.
# Warning: ID 285633 not found in seq_length.
# Warning: ID 285635 not found in seq_length.
# Warning: ID 285638 not found in seq_length.
# Warning: ID 285639 not found in seq_length.
# Warning: ID 285642 not found in seq_length.
# Warning: ID 285643 not found in seq_length.
# Warning: ID 285644 not found in seq_length.
# Warning: ID 285652 not found in seq_length.
# Warning: ID 285654 not found in seq_length.
# Warning: ID 285661 not found in seq_length.
# Warning: ID 285664 not found in seq_length.
# Warning: ID 285665 not found in seq_length.
# Warning: ID 285666 not found in seq_length.
# Warning: ID 285673 not found in seq_length.
# Warning: ID 285677 not found in seq_length.
# Warning: ID 285691 not found in seq_length.
# Warning: ID 285693 not found in seq_length.
# Warning: ID 285695 not found in seq_length.
# Warning: ID 285700 not found in seq_length.
# Warning: ID 285704 not found in seq_length.
# Warning: ID 285709 not found in seq_length.
# Warning: ID 285710 not found in seq_length.
# Warning: ID 285711 not found in seq_length.
# Warning: ID 285715 not found in seq_length.
# Warning: ID 285718 not found in seq_length.
# Warning: ID 285720 not found in seq_length.
# Warning: ID 285722 not found in seq_length.
# Warning: ID 285723 not found in seq_length.
# Warning: ID 285726 not found in seq_length.
# Warning: ID 285731 not found in seq_length.
# Warning: ID 285737 not found in seq_length.
# Warning: ID 285740 not found in seq_length.
# Warning: ID 285742 not found in seq_length.
# Warning: ID 285747 not found in seq_length.
# Warning: ID 285753 not found in seq_length.
# Warning: ID 285754 not found in seq_length.
# Warning: ID 285756 not found in seq_length.
# Warning: ID 285762 not found in seq_length.
# Warning: ID 285765 not found in seq_length.
# Warning: ID 285777 not found in seq_length.
# Warning: ID 285782 not found in seq_length.
# Warning: ID 285783 not found in seq_length.
# Warning: ID 285785 not found in seq_length.
# Warning: ID 285786 not found in seq_length.
# Warning: ID 285787 not found in seq_length.
# Warning: ID 285789 not found in seq_length.
# Warning: ID 285791 not found in seq_length.
# Warning: ID 285797 not found in seq_length.
# Warning: ID 285798 not found in seq_length.
# Warning: ID 285800 not found in seq_length.
# Warning: ID 285805 not found in seq_length.
# Warning: ID 285810 not found in seq_length.
# Warning: ID 285812 not found in seq_length.
# Warning: ID 285823 not found in seq_length.
# Warning: ID 285825 not found in seq_length.
# Warning: ID 285826 not found in seq_length.
# Warning: ID 285827 not found in seq_length.
# Warning: ID 285828 not found in seq_length.
# Warning: ID 285829 not found in seq_length.
# Warning: ID 285830 not found in seq_length.
# Warning: ID 285831 not found in seq_length.
# Warning: ID 285834 not found in seq_length.
# Warning: ID 285837 not found in seq_length.
# Warning: ID 285844 not found in seq_length.
# Warning: ID 285845 not found in seq_length.
# Warning: ID 285846 not found in seq_length.
# Warning: ID 285847 not found in seq_length.
# Warning: ID 285852 not found in seq_length.
# Warning: ID 285856 not found in seq_length.
# Warning: ID 285858 not found in seq_length.
# Warning: ID 285859 not found in seq_length.
# Warning: ID 285865 not found in seq_length.
# Warning: ID 285866 not found in seq_length.
# Warning: ID 285867 not found in seq_length.
# Warning: ID 285872 not found in seq_length.
# Warning: ID 285876 not found in seq_length.
# Warning: ID 285882 not found in seq_length.
# Warning: ID 285885 not found in seq_length.
# Warning: ID 285890 not found in seq_length.
# Warning: ID 285892 not found in seq_length.
# Warning: ID 285895 not found in seq_length.
# Warning: ID 285899 not found in seq_length.
# Warning: ID 285900 not found in seq_length.
# Warning: ID 285901 not found in seq_length.
# Warning: ID 285904 not found in seq_length.
# Warning: ID 285909 not found in seq_length.
# Warning: ID 285910 not found in seq_length.
# Warning: ID 285913 not found in seq_length.
# Warning: ID 285914 not found in seq_length.
# Warning: ID 285917 not found in seq_length.
# Warning: ID 285919 not found in seq_length.
# Warning: ID 285922 not found in seq_length.
# Warning: ID 285923 not found in seq_length.
# Warning: ID 285927 not found in seq_length.
# Warning: ID 285930 not found in seq_length.
# Warning: ID 285933 not found in seq_length.
# Warning: ID 285934 not found in seq_length.
# Warning: ID 285940 not found in seq_length.
# Warning: ID 285948 not found in seq_length.
# Warning: ID 285953 not found in seq_length.
# Warning: ID 285955 not found in seq_length.
# Warning: ID 285956 not found in seq_length.
# Warning: ID 285964 not found in seq_length.
# Warning: ID 285966 not found in seq_length.
# Warning: ID 285967 not found in seq_length.
# Warning: ID 285973 not found in seq_length.
# Warning: ID 285976 not found in seq_length.
# Warning: ID 285984 not found in seq_length.
# Warning: ID 285993 not found in seq_length.
# Warning: ID 285994 not found in seq_length.
# Warning: ID 286001 not found in seq_length.
# Warning: ID 286004 not found in seq_length.
# Warning: ID 286009 not found in seq_length.
# Warning: ID 286010 not found in seq_length.
# Warning: ID 286012 not found in seq_length.
# Warning: ID 286013 not found in seq_length.
# Warning: ID 286016 not found in seq_length.
# Warning: ID 286018 not found in seq_length.
# Warning: ID 286024 not found in seq_length.
# Warning: ID 286025 not found in seq_length.
# Warning: ID 286026 not found in seq_length.
# Warning: ID 286027 not found in seq_length.
# Warning: ID 286029 not found in seq_length.
# Warning: ID 286033 not found in seq_length.
# Warning: ID 286034 not found in seq_length.
# Warning: ID 286036 not found in seq_length.
# Warning: ID 286037 not found in seq_length.
# Warning: ID 286039 not found in seq_length.
# Warning: ID 286041 not found in seq_length.
# Warning: ID 286042 not found in seq_length.
# Warning: ID 286045 not found in seq_length.
# Warning: ID 286046 not found in seq_length.
# Warning: ID 286047 not found in seq_length.
# Warning: ID 286055 not found in seq_length.
# Warning: ID 286061 not found in seq_length.
# Warning: ID 286064 not found in seq_length.
# Warning: ID 286065 not found in seq_length.
# Warning: ID 286069 not found in seq_length.
# Warning: ID 286076 not found in seq_length.
# Warning: ID 286077 not found in seq_length.
# Warning: ID 286078 not found in seq_length.
# Warning: ID 286079 not found in seq_length.
# Warning: ID 286080 not found in seq_length.
# Warning: ID 286092 not found in seq_length.
# Warning: ID 286095 not found in seq_length.
# Warning: ID 286096 not found in seq_length.
# Warning: ID 286098 not found in seq_length.
# Warning: ID 286100 not found in seq_length.
# Warning: ID 286103 not found in seq_length.
# Warning: ID 286106 not found in seq_length.
# Warning: ID 286107 not found in seq_length.
# Warning: ID 286115 not found in seq_length.
# Warning: ID 286118 not found in seq_length.
# Warning: ID 286122 not found in seq_length.
# Warning: ID 286123 not found in seq_length.
# Warning: ID 286124 not found in seq_length.
# Warning: ID 286125 not found in seq_length.
# Warning: ID 286130 not found in seq_length.
# Warning: ID 286134 not found in seq_length.
# Warning: ID 286138 not found in seq_length.
# Warning: ID 286152 not found in seq_length.
# Warning: ID 286154 not found in seq_length.
# Warning: ID 286155 not found in seq_length.
# Warning: ID 286157 not found in seq_length.
# Warning: ID 286159 not found in seq_length.
# Warning: ID 286161 not found in seq_length.
# Warning: ID 286162 not found in seq_length.
# Warning: ID 286167 not found in seq_length.
# Warning: ID 286168 not found in seq_length.
# Warning: ID 286170 not found in seq_length.
# Warning: ID 286174 not found in seq_length.
# Warning: ID 286176 not found in seq_length.
# Warning: ID 286177 not found in seq_length.
# Warning: ID 286183 not found in seq_length.
# Warning: ID 286184 not found in seq_length.
# Warning: ID 286185 not found in seq_length.
# Warning: ID 286187 not found in seq_length.
# Warning: ID 286188 not found in seq_length.
# Warning: ID 286189 not found in seq_length.
# Warning: ID 286193 not found in seq_length.
# Warning: ID 286196 not found in seq_length.
# Warning: ID 286197 not found in seq_length.
# Warning: ID 286198 not found in seq_length.
# Warning: ID 286203 not found in seq_length.
# Warning: ID 286204 not found in seq_length.
# Warning: ID 286205 not found in seq_length.
# Warning: ID 286206 not found in seq_length.
# Warning: ID 286209 not found in seq_length.
# Warning: ID 286213 not found in seq_length.
# Warning: ID 286215 not found in seq_length.
# Warning: ID 286217 not found in seq_length.
# Warning: ID 286218 not found in seq_length.
# Warning: ID 286222 not found in seq_length.
# Warning: ID 286227 not found in seq_length.
# Warning: ID 286230 not found in seq_length.
# Warning: ID 286232 not found in seq_length.
# Warning: ID 286234 not found in seq_length.
# Warning: ID 286235 not found in seq_length.
# Warning: ID 286236 not found in seq_length.
# Warning: ID 286243 not found in seq_length.
# Warning: ID 286245 not found in seq_length.
# Warning: ID 286247 not found in seq_length.
# Warning: ID 286248 not found in seq_length.
# Warning: ID 286251 not found in seq_length.
# Warning: ID 286252 not found in seq_length.
# Warning: ID 286253 not found in seq_length.
# Warning: ID 286254 not found in seq_length.
# Warning: ID 286261 not found in seq_length.
# Warning: ID 286264 not found in seq_length.
# Warning: ID 286267 not found in seq_length.
# Warning: ID 286268 not found in seq_length.
# Warning: ID 286269 not found in seq_length.
# Warning: ID 286271 not found in seq_length.
# Warning: ID 286276 not found in seq_length.
# Warning: ID 286278 not found in seq_length.
# Warning: ID 286283 not found in seq_length.
# Warning: ID 286284 not found in seq_length.
# Warning: ID 286285 not found in seq_length.
# Warning: ID 286287 not found in seq_length.
# Warning: ID 286289 not found in seq_length.
# Warning: ID 286290 not found in seq_length.
# Warning: ID 286293 not found in seq_length.
# Warning: ID 286294 not found in seq_length.
# Warning: ID 286296 not found in seq_length.
# Warning: ID 286299 not found in seq_length.
# Warning: ID 286300 not found in seq_length.
# Warning: ID 286303 not found in seq_length.
# Warning: ID 286308 not found in seq_length.
# Warning: ID 286314 not found in seq_length.
# Warning: ID 286315 not found in seq_length.
# Warning: ID 286316 not found in seq_length.
# Warning: ID 286322 not found in seq_length.
# Warning: ID 286323 not found in seq_length.
# Warning: ID 286324 not found in seq_length.
# Warning: ID 286325 not found in seq_length.
# Warning: ID 286327 not found in seq_length.
# Warning: ID 286332 not found in seq_length.
# Warning: ID 286335 not found in seq_length.
# Warning: ID 286336 not found in seq_length.
# Warning: ID 286346 not found in seq_length.
# Warning: ID 286350 not found in seq_length.
# Warning: ID 286358 not found in seq_length.
# Warning: ID 286364 not found in seq_length.
# Warning: ID 286366 not found in seq_length.
# Warning: ID 286367 not found in seq_length.
# Warning: ID 286372 not found in seq_length.
# Warning: ID 286373 not found in seq_length.
# Warning: ID 286375 not found in seq_length.
# Warning: ID 286377 not found in seq_length.
# Warning: ID 286382 not found in seq_length.
# Warning: ID 286385 not found in seq_length.
# Warning: ID 286387 not found in seq_length.
# Warning: ID 286388 not found in seq_length.
# Warning: ID 286389 not found in seq_length.
# Warning: ID 286390 not found in seq_length.
# Warning: ID 286392 not found in seq_length.
# Warning: ID 286393 not found in seq_length.
# Warning: ID 286395 not found in seq_length.
# Warning: ID 286397 not found in seq_length.
# Warning: ID 286401 not found in seq_length.
# Warning: ID 286402 not found in seq_length.
# Warning: ID 286403 not found in seq_length.
# Warning: ID 286406 not found in seq_length.
# Warning: ID 286411 not found in seq_length.
# Warning: ID 286415 not found in seq_length.
# Warning: ID 286419 not found in seq_length.
# Warning: ID 286420 not found in seq_length.
# Warning: ID 286422 not found in seq_length.
# Warning: ID 286423 not found in seq_length.
# Warning: ID 286433 not found in seq_length.
# Warning: ID 286436 not found in seq_length.
# Warning: ID 286443 not found in seq_length.
# Warning: ID 286444 not found in seq_length.
# Warning: ID 286445 not found in seq_length.
# Warning: ID 286446 not found in seq_length.
# Warning: ID 286447 not found in seq_length.
# Warning: ID 286453 not found in seq_length.
# Warning: ID 286454 not found in seq_length.
# Warning: ID 286458 not found in seq_length.
# Warning: ID 286459 not found in seq_length.
# Warning: ID 286465 not found in seq_length.
# Warning: ID 286466 not found in seq_length.
# Warning: ID 286470 not found in seq_length.
# Warning: ID 286474 not found in seq_length.
# Warning: ID 286475 not found in seq_length.
# Warning: ID 286476 not found in seq_length.
# Warning: ID 286485 not found in seq_length.
# Warning: ID 286486 not found in seq_length.
# Warning: ID 286487 not found in seq_length.
# Warning: ID 286488 not found in seq_length.
# Warning: ID 286489 not found in seq_length.
# Warning: ID 286492 not found in seq_length.
# Warning: ID 286495 not found in seq_length.
# Warning: ID 286499 not found in seq_length.
# Warning: ID 286500 not found in seq_length.
# Warning: ID 286505 not found in seq_length.
# Warning: ID 286506 not found in seq_length.
# Warning: ID 286515 not found in seq_length.
# Warning: ID 286516 not found in seq_length.
# Warning: ID 286518 not found in seq_length.
# Warning: ID 286519 not found in seq_length.
# Warning: ID 286521 not found in seq_length.
# Warning: ID 286523 not found in seq_length.
# Warning: ID 286526 not found in seq_length.
# Warning: ID 286534 not found in seq_length.
# Warning: ID 286538 not found in seq_length.
# Warning: ID 286539 not found in seq_length.
# Warning: ID 286540 not found in seq_length.
# Warning: ID 286543 not found in seq_length.
# Warning: ID 286544 not found in seq_length.
# Warning: ID 286546 not found in seq_length.
# Warning: ID 286547 not found in seq_length.
# Warning: ID 286549 not found in seq_length.
# Warning: ID 286552 not found in seq_length.
# Warning: ID 286555 not found in seq_length.
# Warning: ID 286559 not found in seq_length.
# Warning: ID 286560 not found in seq_length.
# Warning: ID 286561 not found in seq_length.
# Warning: ID 286562 not found in seq_length.
# Warning: ID 286563 not found in seq_length.
# Warning: ID 286565 not found in seq_length.
# Warning: ID 286567 not found in seq_length.
# Warning: ID 286570 not found in seq_length.
# Warning: ID 286574 not found in seq_length.
# Warning: ID 286586 not found in seq_length.
# Warning: ID 286587 not found in seq_length.
# Warning: ID 286597 not found in seq_length.
# Warning: ID 286600 not found in seq_length.
# Warning: ID 286602 not found in seq_length.
# Warning: ID 286604 not found in seq_length.
# Warning: ID 286606 not found in seq_length.
# Warning: ID 286607 not found in seq_length.
# Warning: ID 286609 not found in seq_length.
# Warning: ID 286610 not found in seq_length.
# Warning: ID 286612 not found in seq_length.
# Warning: ID 286613 not found in seq_length.
# Warning: ID 286614 not found in seq_length.
# Warning: ID 286615 not found in seq_length.
# Warning: ID 286617 not found in seq_length.
# Warning: ID 286619 not found in seq_length.
# Warning: ID 286620 not found in seq_length.
# Warning: ID 286621 not found in seq_length.
# Warning: ID 286623 not found in seq_length.
# Warning: ID 286624 not found in seq_length.
# Warning: ID 286625 not found in seq_length.
# Warning: ID 286627 not found in seq_length.
# Warning: ID 286634 not found in seq_length.
# Warning: ID 286635 not found in seq_length.
# Warning: ID 286636 not found in seq_length.
# Warning: ID 286638 not found in seq_length.
# Warning: ID 286644 not found in seq_length.
# Warning: ID 286651 not found in seq_length.
# Warning: ID 286655 not found in seq_length.
# Warning: ID 286658 not found in seq_length.
# Warning: ID 286660 not found in seq_length.
# Warning: ID 286661 not found in seq_length.
# Warning: ID 286662 not found in seq_length.
# Warning: ID 286664 not found in seq_length.
# Warning: ID 286668 not found in seq_length.
# Warning: ID 286681 not found in seq_length.
# Warning: ID 286683 not found in seq_length.
# Warning: ID 286687 not found in seq_length.
# Warning: ID 286693 not found in seq_length.
# Warning: ID 286695 not found in seq_length.
# Warning: ID 286698 not found in seq_length.
# Warning: ID 286706 not found in seq_length.
# Warning: ID 286707 not found in seq_length.
# Warning: ID 286713 not found in seq_length.
# Warning: ID 286715 not found in seq_length.
# Warning: ID 286716 not found in seq_length.
# Warning: ID 286720 not found in seq_length.
# Warning: ID 286721 not found in seq_length.
# Warning: ID 286722 not found in seq_length.
# Warning: ID 286723 not found in seq_length.
# Warning: ID 286726 not found in seq_length.
# Warning: ID 286728 not found in seq_length.
# Warning: ID 286731 not found in seq_length.
# Warning: ID 286735 not found in seq_length.
# Warning: ID 286743 not found in seq_length.
# Warning: ID 286744 not found in seq_length.
# Warning: ID 286750 not found in seq_length.
# Warning: ID 286751 not found in seq_length.
# Warning: ID 286752 not found in seq_length.
# Warning: ID 286754 not found in seq_length.
# Warning: ID 286755 not found in seq_length.
# Warning: ID 286756 not found in seq_length.
# Warning: ID 286758 not found in seq_length.
# Warning: ID 286760 not found in seq_length.
# Warning: ID 286765 not found in seq_length.
# Warning: ID 286770 not found in seq_length.
# Warning: ID 286772 not found in seq_length.
# Warning: ID 286773 not found in seq_length.
# Warning: ID 286775 not found in seq_length.
# Warning: ID 286784 not found in seq_length.
# Warning: ID 286787 not found in seq_length.
# Warning: ID 286788 not found in seq_length.
# Warning: ID 286789 not found in seq_length.
# Warning: ID 286792 not found in seq_length.
# Warning: ID 286796 not found in seq_length.
# Warning: ID 286800 not found in seq_length.
# Warning: ID 286802 not found in seq_length.
# Warning: ID 286807 not found in seq_length.
# Warning: ID 286809 not found in seq_length.
# Warning: ID 286810 not found in seq_length.
# Warning: ID 286811 not found in seq_length.
# Warning: ID 286818 not found in seq_length.
# Warning: ID 286821 not found in seq_length.
# Warning: ID 286822 not found in seq_length.
# Warning: ID 286824 not found in seq_length.
# Warning: ID 286828 not found in seq_length.
# Warning: ID 286832 not found in seq_length.
# Warning: ID 286833 not found in seq_length.
# Warning: ID 286834 not found in seq_length.
# Warning: ID 286835 not found in seq_length.
# Warning: ID 286837 not found in seq_length.
# Warning: ID 286838 not found in seq_length.
# Warning: ID 286839 not found in seq_length.
# Warning: ID 286843 not found in seq_length.
# Warning: ID 286851 not found in seq_length.
# Warning: ID 286852 not found in seq_length.
# Warning: ID 286853 not found in seq_length.
# Warning: ID 286855 not found in seq_length.
# Warning: ID 286856 not found in seq_length.
# Warning: ID 286857 not found in seq_length.
# Warning: ID 286858 not found in seq_length.
# Warning: ID 286863 not found in seq_length.
# Warning: ID 286864 not found in seq_length.
# Warning: ID 286867 not found in seq_length.
# Warning: ID 286871 not found in seq_length.
# Warning: ID 286874 not found in seq_length.
# Warning: ID 286875 not found in seq_length.
# Warning: ID 286876 not found in seq_length.
# Warning: ID 286879 not found in seq_length.
# Warning: ID 286881 not found in seq_length.
# Warning: ID 286883 not found in seq_length.
# Warning: ID 286885 not found in seq_length.
# Warning: ID 286886 not found in seq_length.
# Warning: ID 286891 not found in seq_length.
# Warning: ID 286894 not found in seq_length.
# Warning: ID 286897 not found in seq_length.
# Warning: ID 286898 not found in seq_length.
# Warning: ID 286900 not found in seq_length.
# Warning: ID 286903 not found in seq_length.
# Warning: ID 286904 not found in seq_length.
# Warning: ID 286908 not found in seq_length.
# Warning: ID 286910 not found in seq_length.
# Warning: ID 286911 not found in seq_length.
# Warning: ID 286913 not found in seq_length.
# Warning: ID 286914 not found in seq_length.
# Warning: ID 286916 not found in seq_length.
# Warning: ID 286918 not found in seq_length.
# Warning: ID 286923 not found in seq_length.
# Warning: ID 286925 not found in seq_length.
# Warning: ID 286926 not found in seq_length.
# Warning: ID 286927 not found in seq_length.
# Warning: ID 286928 not found in seq_length.
# Warning: ID 286931 not found in seq_length.
# Warning: ID 286933 not found in seq_length.
# Warning: ID 286934 not found in seq_length.
# Warning: ID 286938 not found in seq_length.
# Warning: ID 286940 not found in seq_length.
# Warning: ID 286941 not found in seq_length.
# Warning: ID 286951 not found in seq_length.
# Warning: ID 286952 not found in seq_length.
# Warning: ID 286953 not found in seq_length.
# Warning: ID 286956 not found in seq_length.
# Warning: ID 286957 not found in seq_length.
# Warning: ID 286962 not found in seq_length.
# Warning: ID 286963 not found in seq_length.
# Warning: ID 286965 not found in seq_length.
# Warning: ID 286967 not found in seq_length.
# Warning: ID 286968 not found in seq_length.
# Warning: ID 286971 not found in seq_length.
# Warning: ID 286972 not found in seq_length.
# Warning: ID 286975 not found in seq_length.
# Warning: ID 286977 not found in seq_length.
# Warning: ID 286978 not found in seq_length.
# Warning: ID 286980 not found in seq_length.
# Warning: ID 286982 not found in seq_length.
# Warning: ID 286983 not found in seq_length.
# Warning: ID 286984 not found in seq_length.
# Warning: ID 286985 not found in seq_length.
# Warning: ID 286987 not found in seq_length.
# Warning: ID 286989 not found in seq_length.
# Warning: ID 286995 not found in seq_length.
# Warning: ID 286999 not found in seq_length.
# Warning: ID 287001 not found in seq_length.
# Warning: ID 287002 not found in seq_length.
# Warning: ID 287012 not found in seq_length.
# Warning: ID 287022 not found in seq_length.
# Warning: ID 287023 not found in seq_length.
# Warning: ID 287025 not found in seq_length.
# Warning: ID 287026 not found in seq_length.
# Warning: ID 287029 not found in seq_length.
# Warning: ID 287039 not found in seq_length.
# Warning: ID 287042 not found in seq_length.
# Warning: ID 287043 not found in seq_length.
# Warning: ID 287045 not found in seq_length.
# Warning: ID 287054 not found in seq_length.
# Warning: ID 287055 not found in seq_length.
# Warning: ID 287059 not found in seq_length.
# Warning: ID 287060 not found in seq_length.
# Warning: ID 287061 not found in seq_length.
# Warning: ID 287062 not found in seq_length.
# Warning: ID 287065 not found in seq_length.
# Warning: ID 287070 not found in seq_length.
# Warning: ID 287072 not found in seq_length.
# Warning: ID 287080 not found in seq_length.
# Warning: ID 287081 not found in seq_length.
# Warning: ID 287085 not found in seq_length.
# Warning: ID 287088 not found in seq_length.
# Warning: ID 287089 not found in seq_length.
# Warning: ID 287090 not found in seq_length.
# Warning: ID 287095 not found in seq_length.
# Warning: ID 287097 not found in seq_length.
# Warning: ID 287101 not found in seq_length.
# Warning: ID 287104 not found in seq_length.
# Warning: ID 287110 not found in seq_length.
# Warning: ID 287114 not found in seq_length.
# Warning: ID 287115 not found in seq_length.
# Warning: ID 287118 not found in seq_length.
# Warning: ID 287119 not found in seq_length.
# Warning: ID 287125 not found in seq_length.
# Warning: ID 287128 not found in seq_length.
# Warning: ID 287130 not found in seq_length.
# Warning: ID 287133 not found in seq_length.
# Warning: ID 287135 not found in seq_length.
# Warning: ID 287137 not found in seq_length.
# Warning: ID 287141 not found in seq_length.
# Warning: ID 287150 not found in seq_length.
# Warning: ID 287154 not found in seq_length.
# Warning: ID 287156 not found in seq_length.
# Warning: ID 287158 not found in seq_length.
# Warning: ID 287161 not found in seq_length.
# Warning: ID 287169 not found in seq_length.
# Warning: ID 287170 not found in seq_length.
# Warning: ID 287178 not found in seq_length.
# Warning: ID 287180 not found in seq_length.
# Warning: ID 287182 not found in seq_length.
# Warning: ID 287183 not found in seq_length.
# Warning: ID 287185 not found in seq_length.
# Warning: ID 287191 not found in seq_length.
# Warning: ID 287198 not found in seq_length.
# Warning: ID 287203 not found in seq_length.
# Warning: ID 287205 not found in seq_length.
# Warning: ID 287207 not found in seq_length.
# Warning: ID 287208 not found in seq_length.
# Warning: ID 287210 not found in seq_length.
# Warning: ID 287212 not found in seq_length.
# Warning: ID 287213 not found in seq_length.
# Warning: ID 287218 not found in seq_length.
# Warning: ID 287220 not found in seq_length.
# Warning: ID 287221 not found in seq_length.
# Warning: ID 287222 not found in seq_length.
# Warning: ID 287227 not found in seq_length.
# Warning: ID 287229 not found in seq_length.
# Warning: ID 287231 not found in seq_length.
# Warning: ID 287232 not found in seq_length.
# Warning: ID 287235 not found in seq_length.
# Warning: ID 287239 not found in seq_length.
# Warning: ID 287245 not found in seq_length.
# Warning: ID 287246 not found in seq_length.
# Warning: ID 287247 not found in seq_length.
# Warning: ID 287250 not found in seq_length.
# Warning: ID 287252 not found in seq_length.
# Warning: ID 287254 not found in seq_length.
# Warning: ID 287256 not found in seq_length.
# Warning: ID 287257 not found in seq_length.
# Warning: ID 287263 not found in seq_length.
# Warning: ID 287270 not found in seq_length.
# Warning: ID 287272 not found in seq_length.
# Warning: ID 287273 not found in seq_length.
# Warning: ID 287277 not found in seq_length.
# Warning: ID 287278 not found in seq_length.
# Warning: ID 287280 not found in seq_length.
# Warning: ID 287282 not found in seq_length.
# Warning: ID 287288 not found in seq_length.
# Warning: ID 287290 not found in seq_length.
# Warning: ID 287296 not found in seq_length.
# Warning: ID 287298 not found in seq_length.
# Warning: ID 287303 not found in seq_length.
# Warning: ID 287305 not found in seq_length.
# Warning: ID 287310 not found in seq_length.
# Warning: ID 287313 not found in seq_length.
# Warning: ID 287314 not found in seq_length.
# Warning: ID 287317 not found in seq_length.
# Warning: ID 287320 not found in seq_length.
# Warning: ID 287326 not found in seq_length.
# Warning: ID 287328 not found in seq_length.
# Warning: ID 287336 not found in seq_length.
# Warning: ID 287337 not found in seq_length.
# Warning: ID 287342 not found in seq_length.
# Warning: ID 287343 not found in seq_length.
# Warning: ID 287345 not found in seq_length.
# Warning: ID 287348 not found in seq_length.
# Warning: ID 287349 not found in seq_length.
# Warning: ID 287350 not found in seq_length.
# Warning: ID 287360 not found in seq_length.
# Warning: ID 287363 not found in seq_length.
# Warning: ID 287366 not found in seq_length.
# Warning: ID 287367 not found in seq_length.
# Warning: ID 287369 not found in seq_length.
# Warning: ID 287370 not found in seq_length.
# Warning: ID 287371 not found in seq_length.
# Warning: ID 287372 not found in seq_length.
# Warning: ID 287373 not found in seq_length.
# Warning: ID 287375 not found in seq_length.
# Warning: ID 287376 not found in seq_length.
# Warning: ID 287377 not found in seq_length.
# Warning: ID 287378 not found in seq_length.
# Warning: ID 287379 not found in seq_length.
# Warning: ID 287381 not found in seq_length.
# Warning: ID 287382 not found in seq_length.
# Warning: ID 287383 not found in seq_length.
# Warning: ID 287384 not found in seq_length.
# Warning: ID 287391 not found in seq_length.
# Warning: ID 287396 not found in seq_length.
# Warning: ID 287402 not found in seq_length.
# Warning: ID 287406 not found in seq_length.
# Warning: ID 287414 not found in seq_length.
# Warning: ID 287417 not found in seq_length.
# Warning: ID 287418 not found in seq_length.
# Warning: ID 287419 not found in seq_length.
# Warning: ID 287423 not found in seq_length.
# Warning: ID 287426 not found in seq_length.
# Warning: ID 287432 not found in seq_length.
# Warning: ID 287434 not found in seq_length.
# Warning: ID 287436 not found in seq_length.
# Warning: ID 287437 not found in seq_length.
# Warning: ID 287441 not found in seq_length.
# Warning: ID 287447 not found in seq_length.
# Warning: ID 287448 not found in seq_length.
# Warning: ID 287451 not found in seq_length.
# Warning: ID 287452 not found in seq_length.
# Warning: ID 287455 not found in seq_length.
# Warning: ID 287463 not found in seq_length.
# Warning: ID 287466 not found in seq_length.
# Warning: ID 287471 not found in seq_length.
# Warning: ID 287477 not found in seq_length.
# Warning: ID 287478 not found in seq_length.
# Warning: ID 287489 not found in seq_length.
# Warning: ID 287492 not found in seq_length.
# Warning: ID 287493 not found in seq_length.
# Warning: ID 287496 not found in seq_length.
# Warning: ID 287500 not found in seq_length.
# Warning: ID 287501 not found in seq_length.
# Warning: ID 287503 not found in seq_length.
# Warning: ID 287506 not found in seq_length.
# Warning: ID 287509 not found in seq_length.
# Warning: ID 287514 not found in seq_length.
# Warning: ID 287517 not found in seq_length.
# Warning: ID 287518 not found in seq_length.
# Warning: ID 287520 not found in seq_length.
# Warning: ID 287522 not found in seq_length.
# Warning: ID 287523 not found in seq_length.
# Warning: ID 287526 not found in seq_length.
# Warning: ID 287528 not found in seq_length.
# Warning: ID 287531 not found in seq_length.
# Warning: ID 287537 not found in seq_length.
# Warning: ID 287538 not found in seq_length.
# Warning: ID 287542 not found in seq_length.
# Warning: ID 287543 not found in seq_length.
# Warning: ID 287552 not found in seq_length.
# Warning: ID 287555 not found in seq_length.
# Warning: ID 287558 not found in seq_length.
# Warning: ID 287559 not found in seq_length.
# Warning: ID 287562 not found in seq_length.
# Warning: ID 287564 not found in seq_length.
# Warning: ID 287578 not found in seq_length.
# Warning: ID 287580 not found in seq_length.
# Warning: ID 287581 not found in seq_length.
# Warning: ID 287582 not found in seq_length.
# Warning: ID 287584 not found in seq_length.
# Warning: ID 287585 not found in seq_length.
# Warning: ID 287589 not found in seq_length.
# Warning: ID 287592 not found in seq_length.
# Warning: ID 287593 not found in seq_length.
# Warning: ID 287606 not found in seq_length.
# Warning: ID 287609 not found in seq_length.
# Warning: ID 287614 not found in seq_length.
# Warning: ID 287618 not found in seq_length.
# Warning: ID 287622 not found in seq_length.
# Warning: ID 287623 not found in seq_length.
# Warning: ID 287625 not found in seq_length.
# Warning: ID 287629 not found in seq_length.
# Warning: ID 287631 not found in seq_length.
# Warning: ID 287633 not found in seq_length.
# Warning: ID 287636 not found in seq_length.
# Warning: ID 287637 not found in seq_length.
# Warning: ID 287638 not found in seq_length.
# Warning: ID 287643 not found in seq_length.
# Warning: ID 287645 not found in seq_length.
# Warning: ID 287648 not found in seq_length.
# Warning: ID 287654 not found in seq_length.
# Warning: ID 287656 not found in seq_length.
# Warning: ID 287661 not found in seq_length.
# Warning: ID 287663 not found in seq_length.
# Warning: ID 287667 not found in seq_length.
# Warning: ID 287675 not found in seq_length.
# Warning: ID 287678 not found in seq_length.
# Warning: ID 287684 not found in seq_length.
# Warning: ID 287685 not found in seq_length.
# Warning: ID 287688 not found in seq_length.
# Warning: ID 287690 not found in seq_length.
# Warning: ID 287691 not found in seq_length.
# Warning: ID 287693 not found in seq_length.
# Warning: ID 287699 not found in seq_length.
# Warning: ID 287702 not found in seq_length.
# Warning: ID 287708 not found in seq_length.
# Warning: ID 287711 not found in seq_length.
# Warning: ID 287714 not found in seq_length.
# Warning: ID 287720 not found in seq_length.
# Warning: ID 287726 not found in seq_length.
# Warning: ID 287727 not found in seq_length.
# Warning: ID 287733 not found in seq_length.
# Warning: ID 287734 not found in seq_length.
# Warning: ID 287739 not found in seq_length.
# Warning: ID 287740 not found in seq_length.
# Warning: ID 287741 not found in seq_length.
# Warning: ID 287744 not found in seq_length.
# Warning: ID 287757 not found in seq_length.
# Warning: ID 287764 not found in seq_length.
# Warning: ID 287767 not found in seq_length.
# Warning: ID 287771 not found in seq_length.
# Warning: ID 287772 not found in seq_length.
# Warning: ID 287773 not found in seq_length.
# Warning: ID 287776 not found in seq_length.
# Warning: ID 287778 not found in seq_length.
# Warning: ID 287782 not found in seq_length.
# Warning: ID 287786 not found in seq_length.
# Warning: ID 287790 not found in seq_length.
# Warning: ID 287793 not found in seq_length.
# Warning: ID 287794 not found in seq_length.
# Warning: ID 287797 not found in seq_length.
# Warning: ID 287799 not found in seq_length.
# Warning: ID 287802 not found in seq_length.
# Warning: ID 287808 not found in seq_length.
# Warning: ID 287809 not found in seq_length.
# Warning: ID 287810 not found in seq_length.
# Warning: ID 287817 not found in seq_length.
# Warning: ID 287825 not found in seq_length.
# Warning: ID 287828 not found in seq_length.
# Warning: ID 287830 not found in seq_length.
# Warning: ID 287834 not found in seq_length.
# Warning: ID 287835 not found in seq_length.
# Warning: ID 287836 not found in seq_length.
# Warning: ID 287837 not found in seq_length.
# Warning: ID 287840 not found in seq_length.
# Warning: ID 287841 not found in seq_length.
# Warning: ID 287843 not found in seq_length.
# Warning: ID 287844 not found in seq_length.
# Warning: ID 287850 not found in seq_length.
# Warning: ID 287852 not found in seq_length.
# Warning: ID 287856 not found in seq_length.
# Warning: ID 287859 not found in seq_length.
# Warning: ID 287863 not found in seq_length.
# Warning: ID 287866 not found in seq_length.
# Warning: ID 287867 not found in seq_length.
# Warning: ID 287869 not found in seq_length.
# Warning: ID 287870 not found in seq_length.
# Warning: ID 287871 not found in seq_length.
# Warning: ID 287872 not found in seq_length.
# Warning: ID 287875 not found in seq_length.
# Warning: ID 287880 not found in seq_length.
# Warning: ID 287881 not found in seq_length.
# Warning: ID 287882 not found in seq_length.
# Warning: ID 287883 not found in seq_length.
# Warning: ID 287884 not found in seq_length.
# Warning: ID 287886 not found in seq_length.
# Warning: ID 287887 not found in seq_length.
# Warning: ID 287890 not found in seq_length.
# Warning: ID 287896 not found in seq_length.
# Warning: ID 287898 not found in seq_length.
# Warning: ID 287904 not found in seq_length.
# Warning: ID 287905 not found in seq_length.
# Warning: ID 287907 not found in seq_length.
# Warning: ID 287915 not found in seq_length.
# Warning: ID 287916 not found in seq_length.
# Warning: ID 287920 not found in seq_length.
# Warning: ID 287921 not found in seq_length.
# Warning: ID 287922 not found in seq_length.
# Warning: ID 287927 not found in seq_length.
# Warning: ID 287928 not found in seq_length.
# Warning: ID 287929 not found in seq_length.
# Warning: ID 287931 not found in seq_length.
# Warning: ID 287932 not found in seq_length.
# Warning: ID 287935 not found in seq_length.
# Warning: ID 287938 not found in seq_length.
# Warning: ID 287939 not found in seq_length.
# Warning: ID 287941 not found in seq_length.
# Warning: ID 287943 not found in seq_length.
# Warning: ID 287944 not found in seq_length.
# Warning: ID 287945 not found in seq_length.
# Warning: ID 287949 not found in seq_length.
# Warning: ID 287950 not found in seq_length.
# Warning: ID 287951 not found in seq_length.
# Warning: ID 287952 not found in seq_length.
# Warning: ID 287956 not found in seq_length.
# Warning: ID 287964 not found in seq_length.
# Warning: ID 287966 not found in seq_length.
# Warning: ID 287967 not found in seq_length.
# Warning: ID 287968 not found in seq_length.
# Warning: ID 287969 not found in seq_length.
# Warning: ID 287970 not found in seq_length.
# Warning: ID 287971 not found in seq_length.
# Warning: ID 287975 not found in seq_length.
# Warning: ID 287978 not found in seq_length.
# Warning: ID 287979 not found in seq_length.
# Warning: ID 287982 not found in seq_length.
# Warning: ID 287984 not found in seq_length.
# Warning: ID 287985 not found in seq_length.
# Warning: ID 287987 not found in seq_length.
# Warning: ID 287991 not found in seq_length.
# Warning: ID 287997 not found in seq_length.
# Warning: ID 287998 not found in seq_length.
# Warning: ID 287999 not found in seq_length.
# Warning: ID 288014 not found in seq_length.
# Warning: ID 288015 not found in seq_length.
# Warning: ID 288017 not found in seq_length.
# Warning: ID 288018 not found in seq_length.
# Warning: ID 288026 not found in seq_length.
# Warning: ID 288032 not found in seq_length.
# Warning: ID 288034 not found in seq_length.
# Warning: ID 288035 not found in seq_length.
# Warning: ID 288040 not found in seq_length.
# Warning: ID 288042 not found in seq_length.
# Warning: ID 288043 not found in seq_length.
# Warning: ID 288044 not found in seq_length.
# Warning: ID 288046 not found in seq_length.
# Warning: ID 288047 not found in seq_length.
# Warning: ID 288048 not found in seq_length.
# Warning: ID 288056 not found in seq_length.
# Warning: ID 288062 not found in seq_length.
# Warning: ID 288064 not found in seq_length.
# Warning: ID 288065 not found in seq_length.
# Warning: ID 288068 not found in seq_length.
# Warning: ID 288072 not found in seq_length.
# Warning: ID 288076 not found in seq_length.
# Warning: ID 288080 not found in seq_length.
# Warning: ID 288083 not found in seq_length.
# Warning: ID 288086 not found in seq_length.
# Warning: ID 288088 not found in seq_length.
# Warning: ID 288089 not found in seq_length.
# Warning: ID 288095 not found in seq_length.
# Warning: ID 288098 not found in seq_length.
# Warning: ID 288101 not found in seq_length.
# Warning: ID 288104 not found in seq_length.
# Warning: ID 288105 not found in seq_length.
# Warning: ID 288107 not found in seq_length.
# Warning: ID 288109 not found in seq_length.
# Warning: ID 288110 not found in seq_length.
# Warning: ID 288114 not found in seq_length.
# Warning: ID 288116 not found in seq_length.
# Warning: ID 288119 not found in seq_length.
# Warning: ID 288122 not found in seq_length.
# Warning: ID 288125 not found in seq_length.
# Warning: ID 288127 not found in seq_length.
# Warning: ID 288131 not found in seq_length.
# Warning: ID 288132 not found in seq_length.
# Warning: ID 288142 not found in seq_length.
# Warning: ID 288143 not found in seq_length.
# Warning: ID 288145 not found in seq_length.
# Warning: ID 288151 not found in seq_length.
# Warning: ID 288153 not found in seq_length.
# Warning: ID 288154 not found in seq_length.
# Warning: ID 288155 not found in seq_length.
# Warning: ID 288158 not found in seq_length.
# Warning: ID 288159 not found in seq_length.
# Warning: ID 288161 not found in seq_length.
# Warning: ID 288164 not found in seq_length.
# Warning: ID 288165 not found in seq_length.
# Warning: ID 288166 not found in seq_length.
# Warning: ID 288167 not found in seq_length.
# Warning: ID 288169 not found in seq_length.
# Warning: ID 288173 not found in seq_length.
# Warning: ID 288176 not found in seq_length.
# Warning: ID 288179 not found in seq_length.
# Warning: ID 288180 not found in seq_length.
# Warning: ID 288181 not found in seq_length.
# Warning: ID 288183 not found in seq_length.
# Warning: ID 288185 not found in seq_length.
# Warning: ID 288187 not found in seq_length.
# Warning: ID 288188 not found in seq_length.
# Warning: ID 288190 not found in seq_length.
# Warning: ID 288191 not found in seq_length.
# Warning: ID 288192 not found in seq_length.
# Warning: ID 288196 not found in seq_length.
# Warning: ID 288199 not found in seq_length.
# Warning: ID 288201 not found in seq_length.
# Warning: ID 288205 not found in seq_length.
# Warning: ID 288206 not found in seq_length.
# Warning: ID 288208 not found in seq_length.
# Warning: ID 288209 not found in seq_length.
# Warning: ID 288210 not found in seq_length.
# Warning: ID 288215 not found in seq_length.
# Warning: ID 288216 not found in seq_length.
# Warning: ID 288217 not found in seq_length.
# Warning: ID 288225 not found in seq_length.
# Warning: ID 288226 not found in seq_length.
# Warning: ID 288230 not found in seq_length.
# Warning: ID 288234 not found in seq_length.
# Warning: ID 288235 not found in seq_length.
# Warning: ID 288238 not found in seq_length.
# Warning: ID 288240 not found in seq_length.
# Warning: ID 288242 not found in seq_length.
# Warning: ID 288246 not found in seq_length.
# Warning: ID 288251 not found in seq_length.
# Warning: ID 288252 not found in seq_length.
# Warning: ID 288255 not found in seq_length.
# Warning: ID 288256 not found in seq_length.
# Warning: ID 288260 not found in seq_length.
# Warning: ID 288262 not found in seq_length.
# Warning: ID 288268 not found in seq_length.
# Warning: ID 288270 not found in seq_length.
# Warning: ID 288272 not found in seq_length.
# Warning: ID 288273 not found in seq_length.
# Warning: ID 288274 not found in seq_length.
# Warning: ID 288276 not found in seq_length.
# Warning: ID 288278 not found in seq_length.
# Warning: ID 288281 not found in seq_length.
# Warning: ID 288284 not found in seq_length.
# Warning: ID 288285 not found in seq_length.
# Warning: ID 288286 not found in seq_length.
# Warning: ID 288288 not found in seq_length.
# Warning: ID 288290 not found in seq_length.
# Warning: ID 288292 not found in seq_length.
# Warning: ID 288294 not found in seq_length.
# Warning: ID 288296 not found in seq_length.
# Warning: ID 288298 not found in seq_length.
# Warning: ID 288301 not found in seq_length.
# Warning: ID 288304 not found in seq_length.
# Warning: ID 288308 not found in seq_length.
# Warning: ID 288313 not found in seq_length.
# Warning: ID 288314 not found in seq_length.
# Warning: ID 288315 not found in seq_length.
# Warning: ID 288321 not found in seq_length.
# Warning: ID 288323 not found in seq_length.
# Warning: ID 288328 not found in seq_length.
# Warning: ID 288336 not found in seq_length.
# Warning: ID 288338 not found in seq_length.
# Warning: ID 288344 not found in seq_length.
# Warning: ID 288346 not found in seq_length.
# Warning: ID 288349 not found in seq_length.
# Warning: ID 288352 not found in seq_length.
# Warning: ID 288353 not found in seq_length.
# Warning: ID 288355 not found in seq_length.
# Warning: ID 288356 not found in seq_length.
# Warning: ID 288358 not found in seq_length.
# ...
# Warning: ID 298753 not found in seq_length.
# Warning: ID 298759 not found in seq_length.
# Warning: ID 298761 not found in seq_length.
# Warning: ID 298762 not found in seq_length.
# Warning: ID 298770 not found in seq_length.
# Warning: ID 298772 not found in seq_length.
# Warning: ID 298775 not found in seq_length.
# Warning: ID 298778 not found in seq_length.
# Warning: ID 298779 not found in seq_length.
# Warning: ID 298781 not found in seq_length.
# Warning: ID 298782 not found in seq_length.
# Warning: ID 298789 not found in seq_length.
# Warning: ID 298791 not found in seq_length.
# Warning: ID 298792 not found in seq_length.
# Warning: ID 298793 not found in seq_length.
# Warning: ID 298795 not found in seq_length.
# Warning: ID 298806 not found in seq_length.
# Warning: ID 298807 not found in seq_length.
# Warning: ID 298809 not found in seq_length.
# Warning: ID 298812 not found in seq_length.
# Warning: ID 298813 not found in seq_length.
# Warning: ID 298815 not found in seq_length.
# Warning: ID 298819 not found in seq_length.
# Warning: ID 298820 not found in seq_length.
# Warning: ID 298821 not found in seq_length.
# Warning: ID 298825 not found in seq_length.
# Warning: ID 298826 not found in seq_length.
# Warning: ID 298827 not found in seq_length.
# Warning: ID 298829 not found in seq_length.
# Warning: ID 298834 not found in seq_length.
# Warning: ID 298836 not found in seq_length.
# Warning: ID 298842 not found in seq_length.
# Warning: ID 298845 not found in seq_length.
# Warning: ID 298848 not found in seq_length.
# Warning: ID 298854 not found in seq_length.
# Warning: ID 298855 not found in seq_length.
# Warning: ID 298856 not found in seq_length.
# Warning: ID 298857 not found in seq_length.
# Warning: ID 298864 not found in seq_length.
# Warning: ID 298866 not found in seq_length.
# Warning: ID 298873 not found in seq_length.
# Warning: ID 298876 not found in seq_length.
# Warning: ID 298878 not found in seq_length.
# Warning: ID 298880 not found in seq_length.
# Warning: ID 298894 not found in seq_length.
# Warning: ID 298895 not found in seq_length.
# Warning: ID 298898 not found in seq_length.
# Warning: ID 298900 not found in seq_length.
# Warning: ID 298907 not found in seq_length.
# Warning: ID 298908 not found in seq_length.
# Warning: ID 298909 not found in seq_length.
# Warning: ID 298911 not found in seq_length.
# Warning: ID 298912 not found in seq_length.
# Warning: ID 298916 not found in seq_length.
# Warning: ID 298920 not found in seq_length.
# Warning: ID 298923 not found in seq_length.
# Warning: ID 298925 not found in seq_length.
# Warning: ID 298927 not found in seq_length.
# Warning: ID 298933 not found in seq_length.
# Warning: ID 298939 not found in seq_length.
# Warning: ID 298945 not found in seq_length.
# Warning: ID 298952 not found in seq_length.
# Warning: ID 298953 not found in seq_length.
# Warning: ID 298957 not found in seq_length.
# Warning: ID 298959 not found in seq_length.
# Warning: ID 298963 not found in seq_length.
# Warning: ID 298966 not found in seq_length.
# Warning: ID 298967 not found in seq_length.
# Warning: ID 298968 not found in seq_length.
# Warning: ID 298970 not found in seq_length.
# Warning: ID 298974 not found in seq_length.
# Warning: ID 298978 not found in seq_length.
# Warning: ID 298981 not found in seq_length.
# Warning: ID 298982 not found in seq_length.
# Warning: ID 298985 not found in seq_length.
# Warning: ID 298986 not found in seq_length.
# Warning: ID 298988 not found in seq_length.
# Warning: ID 298990 not found in seq_length.
# Warning: ID 298991 not found in seq_length.
# Warning: ID 298992 not found in seq_length.
# Warning: ID 298997 not found in seq_length.
# Warning: ID 298999 not found in seq_length.
# Warning: ID 299001 not found in seq_length.
# Warning: ID 299004 not found in seq_length.
# Warning: ID 299014 not found in seq_length.
# Warning: ID 299018 not found in seq_length.
# Warning: ID 299031 not found in seq_length.
# Warning: ID 299033 not found in seq_length.
# Warning: ID 299036 not found in seq_length.
# Warning: ID 299043 not found in seq_length.
# Warning: ID 299044 not found in seq_length.
# Warning: ID 299046 not found in seq_length.
# Warning: ID 299052 not found in seq_length.
# Warning: ID 299054 not found in seq_length.
# Warning: ID 299057 not found in seq_length.
# Warning: ID 299059 not found in seq_length.
# Warning: ID 299062 not found in seq_length.
# Warning: ID 299066 not found in seq_length.
# Warning: ID 299067 not found in seq_length.
# Warning: ID 299070 not found in seq_length.
# Warning: ID 299071 not found in seq_length.
# Warning: ID 299075 not found in seq_length.
# Warning: ID 299079 not found in seq_length.
# Warning: ID 299082 not found in seq_length.
# Warning: ID 299085 not found in seq_length.
# Warning: ID 299087 not found in seq_length.
# Warning: ID 299093 not found in seq_length.
# Warning: ID 299094 not found in seq_length.
# Warning: ID 299097 not found in seq_length.
# Warning: ID 299102 not found in seq_length.
# Warning: ID 299105 not found in seq_length.
# Warning: ID 299112 not found in seq_length.
# Warning: ID 299113 not found in seq_length.
# Warning: ID 299118 not found in seq_length.
# Warning: ID 299121 not found in seq_length.
# Warning: ID 299124 not found in seq_length.
# Warning: ID 299126 not found in seq_length.
# Warning: ID 299132 not found in seq_length.
# Warning: ID 299144 not found in seq_length.
# Warning: ID 299146 not found in seq_length.
# Warning: ID 299148 not found in seq_length.
# Warning: ID 299149 not found in seq_length.
# Warning: ID 299151 not found in seq_length.
# Warning: ID 299155 not found in seq_length.
# Warning: ID 299163 not found in seq_length.
# Warning: ID 299165 not found in seq_length.
# Warning: ID 299167 not found in seq_length.
# Warning: ID 299170 not found in seq_length.
# Warning: ID 299171 not found in seq_length.
# Warning: ID 299173 not found in seq_length.
# Warning: ID 299175 not found in seq_length.
# Warning: ID 299180 not found in seq_length.
# Warning: ID 299181 not found in seq_length.
# Warning: ID 299183 not found in seq_length.
# Warning: ID 299184 not found in seq_length.
# Warning: ID 299185 not found in seq_length.
# Warning: ID 299186 not found in seq_length.
# Warning: ID 299189 not found in seq_length.
# Warning: ID 299190 not found in seq_length.
# Warning: ID 299198 not found in seq_length.
# Warning: ID 299200 not found in seq_length.
# Warning: ID 299209 not found in seq_length.
# Warning: ID 299210 not found in seq_length.
# Warning: ID 299212 not found in seq_length.
# Warning: ID 299214 not found in seq_length.
# Warning: ID 299216 not found in seq_length.
# Warning: ID 299217 not found in seq_length.
# Warning: ID 299219 not found in seq_length.
# Warning: ID 299222 not found in seq_length.
# Warning: ID 299224 not found in seq_length.
# Warning: ID 299225 not found in seq_length.
# Warning: ID 299226 not found in seq_length.
# Warning: ID 299227 not found in seq_length.
# Warning: ID 299229 not found in seq_length.
# Warning: ID 299235 not found in seq_length.
# Warning: ID 299243 not found in seq_length.
# Warning: ID 299246 not found in seq_length.
# Warning: ID 299248 not found in seq_length.
# Warning: ID 299251 not found in seq_length.
# Warning: ID 299262 not found in seq_length.
# Warning: ID 299265 not found in seq_length.
# Warning: ID 299270 not found in seq_length.
# Warning: ID 299271 not found in seq_length.
# Warning: ID 299274 not found in seq_length.
# Warning: ID 299278 not found in seq_length.
# Warning: ID 299280 not found in seq_length.
# Warning: ID 299285 not found in seq_length.
# Warning: ID 299288 not found in seq_length.
# Warning: ID 299296 not found in seq_length.
# Warning: ID 299298 not found in seq_length.
# Warning: ID 299299 not found in seq_length.
# Warning: ID 299301 not found in seq_length.
# Warning: ID 299302 not found in seq_length.
# Warning: ID 299305 not found in seq_length.
# Warning: ID 299312 not found in seq_length.
# Warning: ID 299318 not found in seq_length.
# Warning: ID 299319 not found in seq_length.
# Warning: ID 299334 not found in seq_length.
# Warning: ID 299336 not found in seq_length.
# Warning: ID 299338 not found in seq_length.
# Warning: ID 299339 not found in seq_length.
# Warning: ID 299340 not found in seq_length.
# Warning: ID 299342 not found in seq_length.
# Warning: ID 299345 not found in seq_length.
# Warning: ID 299349 not found in seq_length.
# Warning: ID 299350 not found in seq_length.
# Warning: ID 299353 not found in seq_length.
# Warning: ID 299359 not found in seq_length.
# Warning: ID 299360 not found in seq_length.
# Warning: ID 299362 not found in seq_length.
# Warning: ID 299366 not found in seq_length.
# Warning: ID 299371 not found in seq_length.
# Warning: ID 299373 not found in seq_length.
# Warning: ID 299374 not found in seq_length.
# Warning: ID 299376 not found in seq_length.
# Warning: ID 299380 not found in seq_length.
# Warning: ID 299383 not found in seq_length.
# Warning: ID 299384 not found in seq_length.
# Warning: ID 299386 not found in seq_length.
# Warning: ID 299388 not found in seq_length.
# Warning: ID 299390 not found in seq_length.
# Warning: ID 299392 not found in seq_length.
# Warning: ID 299393 not found in seq_length.
# Warning: ID 299394 not found in seq_length.
# Warning: ID 299395 not found in seq_length.
# Warning: ID 299398 not found in seq_length.
# Warning: ID 299401 not found in seq_length.
# Warning: ID 299403 not found in seq_length.
# Warning: ID 299410 not found in seq_length.
# Warning: ID 299411 not found in seq_length.
# Warning: ID 299412 not found in seq_length.
# Warning: ID 299415 not found in seq_length.
# Warning: ID 299416 not found in seq_length.
# Warning: ID 299418 not found in seq_length.
# Warning: ID 299421 not found in seq_length.
# Warning: ID 299424 not found in seq_length.
# Warning: ID 299426 not found in seq_length.
# Warning: ID 299434 not found in seq_length.
# Warning: ID 299444 not found in seq_length.
# Warning: ID 299445 not found in seq_length.
# Warning: ID 299448 not found in seq_length.
# Warning: ID 299452 not found in seq_length.
# Warning: ID 299460 not found in seq_length.
# Warning: ID 299461 not found in seq_length.
# Warning: ID 299462 not found in seq_length.
# Warning: ID 299464 not found in seq_length.
# Warning: ID 299465 not found in seq_length.
# Warning: ID 299469 not found in seq_length.
# Warning: ID 299473 not found in seq_length.
# Warning: ID 299476 not found in seq_length.
# Warning: ID 299479 not found in seq_length.
# Warning: ID 299482 not found in seq_length.
# Warning: ID 299483 not found in seq_length.
# Warning: ID 299486 not found in seq_length.
# Warning: ID 299488 not found in seq_length.
# Warning: ID 299490 not found in seq_length.
# Warning: ID 299495 not found in seq_length.
# Warning: ID 299496 not found in seq_length.
# Warning: ID 299498 not found in seq_length.
# Warning: ID 299499 not found in seq_length.
# Warning: ID 299500 not found in seq_length.
# Warning: ID 299502 not found in seq_length.
# Warning: ID 299509 not found in seq_length.
# Warning: ID 299511 not found in seq_length.
# Warning: ID 299512 not found in seq_length.
# Warning: ID 299513 not found in seq_length.
# Warning: ID 299518 not found in seq_length.
# Warning: ID 299520 not found in seq_length.
# Warning: ID 299522 not found in seq_length.
# Warning: ID 299523 not found in seq_length.
# Warning: ID 299524 not found in seq_length.
# Warning: ID 299526 not found in seq_length.
# Warning: ID 299530 not found in seq_length.
# Warning: ID 299531 not found in seq_length.
# Warning: ID 299533 not found in seq_length.
# Warning: ID 299534 not found in seq_length.
# Warning: ID 299535 not found in seq_length.
# Warning: ID 299538 not found in seq_length.
# Warning: ID 299539 not found in seq_length.
# Warning: ID 299543 not found in seq_length.
# Warning: ID 299544 not found in seq_length.
# Warning: ID 299545 not found in seq_length.
# Warning: ID 299547 not found in seq_length.
# Warning: ID 299554 not found in seq_length.
# Warning: ID 299555 not found in seq_length.
# Warning: ID 299557 not found in seq_length.
# Warning: ID 299560 not found in seq_length.
# Warning: ID 299561 not found in seq_length.
# Warning: ID 299569 not found in seq_length.
# Warning: ID 299571 not found in seq_length.
# Warning: ID 299572 not found in seq_length.
# Warning: ID 299573 not found in seq_length.
# Warning: ID 299574 not found in seq_length.
# Warning: ID 299577 not found in seq_length.
# Warning: ID 299579 not found in seq_length.
# Warning: ID 299585 not found in seq_length.
# Warning: ID 299589 not found in seq_length.
# Warning: ID 299590 not found in seq_length.
# Warning: ID 299603 not found in seq_length.
# Warning: ID 299606 not found in seq_length.
# Warning: ID 299609 not found in seq_length.
# Warning: ID 299614 not found in seq_length.
# Warning: ID 299616 not found in seq_length.
# Warning: ID 299623 not found in seq_length.
# Warning: ID 299625 not found in seq_length.
# Warning: ID 299626 not found in seq_length.
# Warning: ID 299628 not found in seq_length.
# Warning: ID 299630 not found in seq_length.
# Warning: ID 299634 not found in seq_length.
# Warning: ID 299635 not found in seq_length.
# Warning: ID 299636 not found in seq_length.
# Warning: ID 299640 not found in seq_length.
# Warning: ID 299645 not found in seq_length.
# Warning: ID 299646 not found in seq_length.
# Warning: ID 299652 not found in seq_length.
# Warning: ID 299653 not found in seq_length.
# Warning: ID 299654 not found in seq_length.
# Warning: ID 299655 not found in seq_length.
# Warning: ID 299656 not found in seq_length.
# Warning: ID 299657 not found in seq_length.
# Warning: ID 299658 not found in seq_length.
# Warning: ID 299660 not found in seq_length.
# Warning: ID 299665 not found in seq_length.
# Warning: ID 299666 not found in seq_length.
# Warning: ID 299671 not found in seq_length.
# Warning: ID 299672 not found in seq_length.
# Warning: ID 299674 not found in seq_length.
# Warning: ID 299678 not found in seq_length.
# Warning: ID 299680 not found in seq_length.
# Warning: ID 299681 not found in seq_length.
# Warning: ID 299685 not found in seq_length.
# Warning: ID 299686 not found in seq_length.
# Warning: ID 299692 not found in seq_length.
# Warning: ID 299695 not found in seq_length.
# Warning: ID 299698 not found in seq_length.
# Warning: ID 299699 not found in seq_length.
# Warning: ID 299703 not found in seq_length.
# Warning: ID 299705 not found in seq_length.
# Warning: ID 299707 not found in seq_length.
# Warning: ID 299708 not found in seq_length.
# Warning: ID 299714 not found in seq_length.
# Warning: ID 299716 not found in seq_length.
# Warning: ID 299721 not found in seq_length.
# Warning: ID 299728 not found in seq_length.
# Warning: ID 299732 not found in seq_length.
# Warning: ID 299736 not found in seq_length.
# Warning: ID 299738 not found in seq_length.
# Warning: ID 299739 not found in seq_length.
# Warning: ID 299740 not found in seq_length.
# Warning: ID 299742 not found in seq_length.
# Warning: ID 299743 not found in seq_length.
# Warning: ID 299746 not found in seq_length.
# Warning: ID 299749 not found in seq_length.
# Warning: ID 299756 not found in seq_length.
# Warning: ID 299758 not found in seq_length.
# Warning: ID 299762 not found in seq_length.
# Warning: ID 299764 not found in seq_length.
# Warning: ID 299765 not found in seq_length.
# Warning: ID 299766 not found in seq_length.
# Warning: ID 299767 not found in seq_length.
# Warning: ID 299769 not found in seq_length.
# Warning: ID 299772 not found in seq_length.
# Warning: ID 299774 not found in seq_length.
# Warning: ID 299775 not found in seq_length.
# Warning: ID 299776 not found in seq_length.
# Warning: ID 299779 not found in seq_length.
# Warning: ID 299780 not found in seq_length.
# Warning: ID 299782 not found in seq_length.
# Warning: ID 299785 not found in seq_length.
# Warning: ID 299790 not found in seq_length.
# Warning: ID 299791 not found in seq_length.
# Warning: ID 299792 not found in seq_length.
# Warning: ID 299794 not found in seq_length.
# Warning: ID 299800 not found in seq_length.
# Warning: ID 299803 not found in seq_length.
# Warning: ID 299807 not found in seq_length.
# Warning: ID 299811 not found in seq_length.
# Warning: ID 299813 not found in seq_length.
# Warning: ID 299816 not found in seq_length.
# Warning: ID 299818 not found in seq_length.
# Warning: ID 299820 not found in seq_length.
# New Length of filtered_id_list: 35781
# New Length of label_list: 1793
# Error: Lengths still do not match.

# %%
print(f"Length of id_test: {len(id_test)}")
print(f"Length of seq_length: {len(seq_length)}")
# Out:
# Length of id_test: 4734
# Length of seq_length: 1793

# %%
# Get the number of elements in index_list
num_elements_index_list = len(index_list)

# Get the number of elements in label_list
num_elements_label_list = len(label_list)

# Print the results
print(f"Number of elements in index_list: {num_elements_index_list}")
print(f"Number of elements in label_list: {num_elements_label_list}")
# Out:
# Number of elements in index_list: 1793
# Number of elements in label_list: 1363

# %%
test.drop(['charttime'], axis=1, inplace = True)
train.drop(['charttime'], axis=1, inplace = True)
validation.drop(['charttime'], axis=1, inplace = True)

# %%
np.version.version
# Out:
# '1.26.4'

# %%
# Group by 'icustay_id' and convert each group to a 2D array
train_sequences = [group.to_numpy() for _, group in train.groupby('icustay_id')]
test_sequences = [group.to_numpy() for _, group in test.groupby('icustay_id')]
validation_sequences = [group.to_numpy() for _, group in validation.groupby('icustay_id')]

# The result is a list of 2D numpy arrays, where each array corresponds to a sequence for a specific icustay_id.

# Example: Print the number of sequences and the shape of the first sequence in each set
print(f"Number of training sequences: {len(train_sequences)}")
print(f"Shape of the first training sequence: {train_sequences[0].shape}")

print(f"Number of test sequences: {len(test_sequences)}")
print(f"Shape of the first test sequence: {test_sequences[0].shape}")

print(f"Number of validation sequences: {len(validation_sequences)}")
print(f"Shape of the first validation sequence: {validation_sequences[0].shape}")
# Out:
# Number of training sequences: 14490
# Shape of the first training sequence: (28, 33)
# Number of test sequences: 1793
# Shape of the first test sequence: (71, 33)
# Number of validation sequences: 1771
# Shape of the first validation sequence: (17, 33)

# %%
print(train.columns)
# Out:
# Index(['icustay_id', 'aniongap_avg', 'bicarbonate_avg', 'bun_avg',
#        'chloride_avg', 'creat', 'diasbp_mean', 'glucose_avg', 'heartrate_mean',
#        'hematocrit_avg', 'hemoglobin_avg', 'potassium_avg', 'resprate_mean',
#        'sodium_avg', 'spo2_mean', 'sysbp_mean', 'uo_rt_12hr', 'uo_rt_24hr',
#        'uo_rt_6hr', 'wbc_avg', 'sedative', 'vasopressor', 'vent', 'age', 'F',
#        'M', 'asian', 'black', 'hispanic', 'native', 'other', 'unknown',
#        'white'],
#       dtype='object')

# %%
print(validation.shape)
# Out:
# (58966, 33)

# %%
def pad_sequences(sequences, fill_value):
    max_length = max(seq.shape[0] for seq in sequences)
    padded_sequences = []
    for seq in sequences:
        padded_seq = np.pad(seq, ((0, max_length - seq.shape[0]), (0, 0)), mode='constant', constant_values=fill_value)
        padded_sequences.append(padded_seq)
    return np.array(padded_sequences)

FILL_VALUE = 0  # Define the fill value for padding
print("Pad the sequences to ensure uniform length")
X_train_padded = pad_sequences(train_sequences, FILL_VALUE)
X_test_padded = pad_sequences(test_sequences, FILL_VALUE)
X_validation_padded = pad_sequences(validation_sequences, FILL_VALUE)

print(f"Padded training data shape: {X_train_padded.shape}")
print(f"Padded test data shape: {X_test_padded.shape}")
print(f"Padded validation data shape: {X_validation_padded.shape}")
# Out:
# Pad the sequences to ensure uniform length
# Padded training data shape: (14490, 227, 33)
# Padded test data shape: (1793, 117, 33)
# Padded validation data shape: (1771, 117, 33)

# %%
print("Flatten the 3D arrays back to 2D arrays")
nsamples, nx, ny = X_train_padded.shape
X_train_flattened = X_train_padded.reshape((nsamples, nx * ny))
print(f"Flattened training data shape: {X_train_flattened.shape}")

nsamples, nx, ny = X_test_padded.shape
X_test_flattened = X_test_padded.reshape((nsamples, nx * ny))
print(f"Flattened test data shape: {X_test_flattened.shape}")

nsamples, nx, ny = X_validation_padded.shape
X_validation_flattened = X_validation_padded.reshape((nsamples, nx * ny))
print(f"Flattened validation data shape: {X_validation_flattened.shape}")
# Out:
# Flatten the 3D arrays back to 2D arrays
# Flattened training data shape: (14490, 7491)
# Flattened test data shape: (1793, 3861)
# Flattened validation data shape: (1771, 3861)

# %%
# Check the lengths of filtered_id_list and label_list
print(f"Length of filtered_id_list: {len(filtered_id_list)}")
print(f"Length of label_list: {len(label_list)}")

# If they do not match, identify where the issue might be
if len(filtered_id_list) != len(label_list):
    print("Error: The lengths of filtered_id_list and label_list do not match.")

    # Optional: Print out the differences or examine the lists
    for i, (id, label) in enumerate(zip(filtered_id_list, label_list)):
        print(f"Index {i}: ID = {id}, Label = {label}")

    # Further debugging steps could include checking unique counts or values in each list
    unique_ids = set(filtered_id_list)
    unique_labels = set(label_list)
    print(f"Unique IDs: {len(unique_ids)}")
    print(f"Unique Labels: {len(unique_labels)}")

    # Exit the code if there is a mismatch to prevent further errors
    raise ValueError("Cannot proceed due to mismatched lengths.")
else:
    print("No length mismatch found.")

# Proceed to create the DataFrame if lengths match
label_register = pd.DataFrame({'icustay_id': filtered_id_list, 'label': label_list})

# Now, merge labels with the original train, test, and validation sets
y_train = label_register.loc[label_register['icustay_id'].isin(id_train), 'label'].values
y_test = label_register.loc[label_register['icustay_id'].isin(id_test), 'label'].values
y_validation = label_register.loc[label_register['icustay_id'].isin(id_valid), 'label'].values

# Convert y values to DataFrames if needed
y_train_df = pd.DataFrame(y_train, columns=['aki_stage'])
y_test_df = pd.DataFrame(y_test, columns=['aki_stage'])
y_validation_df = pd.DataFrame(y_validation, columns=['aki_stage'])
# Out:
# Length of filtered_id_list: 35781
# Length of label_list: 1363
# Error: The lengths of filtered_id_list and label_list do not match.
# Index 0: ID = 200001, Label = 0
# Index 1: ID = 200003, Label = 0
# Index 2: ID = 200006, Label = 0
# Index 3: ID = 200007, Label = 0
# Index 4: ID = 200009, Label = 0
# Index 5: ID = 200014, Label = 0
# Index 6: ID = 200019, Label = 0
# Index 7: ID = 200024, Label = 0
# Index 8: ID = 200025, Label = 0
# Index 9: ID = 200028, Label = 0
# Index 10: ID = 200030, Label = 0
# Index 11: ID = 200033, Label = 0
# Index 12: ID = 200034, Label = 0
# Index 13: ID = 200035, Label = 0
# Index 14: ID = 200036, Label = 0
# Index 15: ID = 200038, Label = 0
# Index 16: ID = 200039, Label = 0
# Index 17: ID = 200041, Label = 0
# Index 18: ID = 200045, Label = 0
# Index 19: ID = 200047, Label = 0
# Index 20: ID = 200049, Label = 0
# Index 21: ID = 200052, Label = 0
# Index 22: ID = 200053, Label = 0
# Index 23: ID = 200055, Label = 0
# Index 24: ID = 200059, Label = 0
# Index 25: ID = 200061, Label = 0
# Index 26: ID = 200062, Label = 0
# Index 27: ID = 200063, Label = 0
# Index 28: ID = 200065, Label = 0
# Index 29: ID = 200066, Label = 0
# Index 30: ID = 200067, Label = 0
# Index 31: ID = 200068, Label = 0
# Index 32: ID = 200069, Label = 0
# Index 33: ID = 200071, Label = 0
# Index 34: ID = 200072, Label = 0
# Index 35: ID = 200075, Label = 0
# Index 36: ID = 200077, Label = 0
# Index 37: ID = 200078, Label = 0
# Index 38: ID = 200079, Label = 0
# Index 39: ID = 200081, Label = 0
# Index 40: ID = 200085, Label = 0
# Index 41: ID = 200087, Label = 0
# Index 42: ID = 200091, Label = 0
# Index 43: ID = 200094, Label = 0
# Index 44: ID = 200095, Label = 0
# Index 45: ID = 200098, Label = 0
# Index 46: ID = 200099, Label = 0
# Index 47: ID = 200102, Label = 0
# Index 48: ID = 200103, Label = 0
# Index 49: ID = 200106, Label = 0
# Index 50: ID = 200108, Label = 0
# Index 51: ID = 200109, Label = 0
# Index 52: ID = 200112, Label = 0
# Index 53: ID = 200116, Label = 0
# Index 54: ID = 200117, Label = 0
# Index 55: ID = 200124, Label = 0
# Index 56: ID = 200125, Label = 0
# Index 57: ID = 200126, Label = 0
# Index 58: ID = 200130, Label = 0
# Index 59: ID = 200131, Label = 0
# Index 60: ID = 200132, Label = 0
# Index 61: ID = 200133, Label = 0
# Index 62: ID = 200135, Label = 0
# Index 63: ID = 200136, Label = 0
# Index 64: ID = 200137, Label = 0
# Index 65: ID = 200138, Label = 0
# Index 66: ID = 200140, Label = 0
# Index 67: ID = 200141, Label = 0
# Index 68: ID = 200143, Label = 0
# Index 69: ID = 200147, Label = 0
# Index 70: ID = 200150, Label = 0
# Index 71: ID = 200153, Label = 0
# Index 72: ID = 200159, Label = 0
# Index 73: ID = 200161, Label = 0
# Index 74: ID = 200162, Label = 0
# Index 75: ID = 200163, Label = 0
# Index 76: ID = 200165, Label = 0
# Index 77: ID = 200166, Label = 0
# Index 78: ID = 200168, Label = 0
# Index 79: ID = 200169, Label = 0
# Index 80: ID = 200172, Label = 0
# Index 81: ID = 200173, Label = 0
# Index 82: ID = 200174, Label = 0
# Index 83: ID = 200179, Label = 0
# Index 84: ID = 200182, Label = 0
# Index 85: ID = 200184, Label = 0
# Index 86: ID = 200185, Label = 0
# Index 87: ID = 200188, Label = 0
# Index 88: ID = 200191, Label = 0
# Index 89: ID = 200192, Label = 0
# Index 90: ID = 200197, Label = 0
# Index 91: ID = 200200, Label = 0
# Index 92: ID = 200201, Label = 0
# Index 93: ID = 200203, Label = 0
# Index 94: ID = 200206, Label = 0
# Index 95: ID = 200208, Label = 0
# Index 96: ID = 200210, Label = 0
# Index 97: ID = 200215, Label = 0
# Index 98: ID = 200217, Label = 0
# Index 99: ID = 200220, Label = 0
# Index 100: ID = 200223, Label = 0
# Index 101: ID = 200224, Label = 0
# Index 102: ID = 200225, Label = 0
# Index 103: ID = 200227, Label = 0
# Index 104: ID = 200229, Label = 0
# Index 105: ID = 200231, Label = 0
# Index 106: ID = 200232, Label = 0
# Index 107: ID = 200234, Label = 0
# Index 108: ID = 200237, Label = 0
# Index 109: ID = 200238, Label = 0
# Index 110: ID = 200240, Label = 0
# Index 111: ID = 200241, Label = 0
# Index 112: ID = 200247, Label = 0
# Index 113: ID = 200249, Label = 0
# Index 114: ID = 200250, Label = 0
# Index 115: ID = 200252, Label = 0
# Index 116: ID = 200256, Label = 0
# Index 117: ID = 200257, Label = 0
# Index 118: ID = 200261, Label = 0
# Index 119: ID = 200262, Label = 0
# Index 120: ID = 200263, Label = 0
# Index 121: ID = 200264, Label = 0
# Index 122: ID = 200265, Label = 0
# Index 123: ID = 200269, Label = 0
# Index 124: ID = 200277, Label = 0
# Index 125: ID = 200284, Label = 0
# Index 126: ID = 200286, Label = 0
# Index 127: ID = 200289, Label = 0
# Index 128: ID = 200290, Label = 0
# Index 129: ID = 200295, Label = 0
# Index 130: ID = 200297, Label = 0
# Index 131: ID = 200298, Label = 0
# Index 132: ID = 200300, Label = 0
# Index 133: ID = 200301, Label = 0
# Index 134: ID = 200303, Label = 0
# Index 135: ID = 200307, Label = 0
# Index 136: ID = 200311, Label = 0
# Index 137: ID = 200312, Label = 0
# Index 138: ID = 200313, Label = 0
# Index 139: ID = 200319, Label = 0
# Index 140: ID = 200320, Label = 0
# Index 141: ID = 200321, Label = 0
# Index 142: ID = 200322, Label = 0
# Index 143: ID = 200324, Label = 0
# Index 144: ID = 200325, Label = 0
# Index 145: ID = 200326, Label = 0
# Index 146: ID = 200328, Label = 0
# Index 147: ID = 200329, Label = 0
# Index 148: ID = 200330, Label = 0
# Index 149: ID = 200335, Label = 0
# Index 150: ID = 200337, Label = 0
# Index 151: ID = 200338, Label = 0
# Index 152: ID = 200339, Label = 0
# Index 153: ID = 200341, Label = 0
# Index 154: ID = 200343, Label = 0
# Index 155: ID = 200346, Label = 0
# Index 156: ID = 200349, Label = 0
# Index 157: ID = 200352, Label = 0
# Index 158: ID = 200357, Label = 0
# Index 159: ID = 200359, Label = 0
# Index 160: ID = 200361, Label = 0
# Index 161: ID = 200367, Label = 0
# Index 162: ID = 200368, Label = 0
# Index 163: ID = 200373, Label = 0
# Index 164: ID = 200379, Label = 0
# Index 165: ID = 200383, Label = 0
# Index 166: ID = 200385, Label = 0
# Index 167: ID = 200386, Label = 0
# Index 168: ID = 200387, Label = 0
# Index 169: ID = 200394, Label = 0
# Index 170: ID = 200398, Label = 0
# Index 171: ID = 200399, Label = 0
# Index 172: ID = 200402, Label = 0
# Index 173: ID = 200403, Label = 0
# Index 174: ID = 200406, Label = 0
# Index 175: ID = 200408, Label = 0
# Index 176: ID = 200410, Label = 0
# Index 177: ID = 200419, Label = 0
# Index 178: ID = 200423, Label = 0
# Index 179: ID = 200428, Label = 0
# Index 180: ID = 200429, Label = 0
# Index 181: ID = 200430, Label = 0
# Index 182: ID = 200432, Label = 0
# Index 183: ID = 200434, Label = 0
# Index 184: ID = 200438, Label = 0
# Index 185: ID = 200439, Label = 0
# Index 186: ID = 200445, Label = 0
# Index 187: ID = 200450, Label = 0
# Index 188: ID = 200451, Label = 0
# Index 189: ID = 200453, Label = 0
# Index 190: ID = 200454, Label = 0
# Index 191: ID = 200455, Label = 0
# Index 192: ID = 200456, Label = 0
# Index 193: ID = 200457, Label = 0
# Index 194: ID = 200459, Label = 0
# Index 195: ID = 200460, Label = 0
# Index 196: ID = 200465, Label = 0
# Index 197: ID = 200467, Label = 0
# Index 198: ID = 200468, Label = 0
# Index 199: ID = 200474, Label = 0
# Index 200: ID = 200475, Label = 0
# Index 201: ID = 200477, Label = 0
# Index 202: ID = 200481, Label = 0
# Index 203: ID = 200483, Label = 0
# Index 204: ID = 200485, Label = 0
# Index 205: ID = 200486, Label = 0
# Index 206: ID = 200488, Label = 0
# Index 207: ID = 200490, Label = 0
# Index 208: ID = 200492, Label = 0
# Index 209: ID = 200496, Label = 0
# Index 210: ID = 200509, Label = 0
# Index 211: ID = 200513, Label = 0
# Index 212: ID = 200517, Label = 0
# Index 213: ID = 200524, Label = 0
# Index 214: ID = 200526, Label = 0
# Index 215: ID = 200529, Label = 0
# Index 216: ID = 200530, Label = 0
# Index 217: ID = 200535, Label = 0
# Index 218: ID = 200539, Label = 0
# Index 219: ID = 200547, Label = 0
# Index 220: ID = 200548, Label = 0
# Index 221: ID = 200550, Label = 0
# Index 222: ID = 200552, Label = 0
# Index 223: ID = 200559, Label = 0
# Index 224: ID = 200560, Label = 0
# Index 225: ID = 200561, Label = 0
# Index 226: ID = 200566, Label = 0
# Index 227: ID = 200569, Label = 0
# Index 228: ID = 200571, Label = 0
# Index 229: ID = 200575, Label = 0
# Index 230: ID = 200579, Label = 0
# Index 231: ID = 200583, Label = 0
# Index 232: ID = 200584, Label = 0
# Index 233: ID = 200590, Label = 0
# Index 234: ID = 200594, Label = 0
# Index 235: ID = 200597, Label = 0
# Index 236: ID = 200603, Label = 0
# Index 237: ID = 200608, Label = 0
# Index 238: ID = 200610, Label = 0
# Index 239: ID = 200612, Label = 0
# Index 240: ID = 200614, Label = 0
# Index 241: ID = 200616, Label = 0
# Index 242: ID = 200620, Label = 0
# Index 243: ID = 200622, Label = 0
# Index 244: ID = 200625, Label = 0
# Index 245: ID = 200635, Label = 0
# Index 246: ID = 200637, Label = 0
# Index 247: ID = 200638, Label = 0
# Index 248: ID = 200641, Label = 0
# Index 249: ID = 200642, Label = 0
# Index 250: ID = 200647, Label = 0
# Index 251: ID = 200653, Label = 0
# Index 252: ID = 200654, Label = 0
# Index 253: ID = 200656, Label = 0
# Index 254: ID = 200657, Label = 0
# Index 255: ID = 200659, Label = 0
# Index 256: ID = 200661, Label = 0
# Index 257: ID = 200662, Label = 0
# Index 258: ID = 200664, Label = 0
# Index 259: ID = 200665, Label = 0
# Index 260: ID = 200671, Label = 0
# Index 261: ID = 200674, Label = 0
# Index 262: ID = 200677, Label = 0
# Index 263: ID = 200678, Label = 0
# Index 264: ID = 200680, Label = 0
# Index 265: ID = 200681, Label = 0
# Index 266: ID = 200684, Label = 0
# Index 267: ID = 200685, Label = 0
# Index 268: ID = 200686, Label = 0
# Index 269: ID = 200694, Label = 0
# Index 270: ID = 200696, Label = 0
# Index 271: ID = 200697, Label = 0
# Index 272: ID = 200701, Label = 0
# Index 273: ID = 200708, Label = 0
# Index 274: ID = 200710, Label = 0
# Index 275: ID = 200711, Label = 0
# Index 276: ID = 200712, Label = 0
# Index 277: ID = 200713, Label = 0
# Index 278: ID = 200718, Label = 0
# Index 279: ID = 200723, Label = 0
# Index 280: ID = 200724, Label = 0
# Index 281: ID = 200726, Label = 0
# Index 282: ID = 200728, Label = 0
# Index 283: ID = 200729, Label = 0
# Index 284: ID = 200730, Label = 0
# Index 285: ID = 200733, Label = 0
# Index 286: ID = 200735, Label = 0
# Index 287: ID = 200737, Label = 0
# Index 288: ID = 200738, Label = 0
# Index 289: ID = 200744, Label = 0
# Index 290: ID = 200746, Label = 0
# Index 291: ID = 200747, Label = 0
# Index 292: ID = 200748, Label = 0
# Index 293: ID = 200749, Label = 0
# Index 294: ID = 200751, Label = 0
# Index 295: ID = 200753, Label = 0
# Index 296: ID = 200755, Label = 0
# Index 297: ID = 200757, Label = 0
# Index 298: ID = 200758, Label = 0
# Index 299: ID = 200759, Label = 0
# Index 300: ID = 200761, Label = 0
# Index 301: ID = 200764, Label = 0
# Index 302: ID = 200769, Label = 0
# Index 303: ID = 200770, Label = 0
# Index 304: ID = 200771, Label = 0
# Index 305: ID = 200773, Label = 0
# Index 306: ID = 200774, Label = 0
# Index 307: ID = 200777, Label = 0
# Index 308: ID = 200779, Label = 0
# Index 309: ID = 200783, Label = 0
# Index 310: ID = 200786, Label = 0
# Index 311: ID = 200788, Label = 0
# Index 312: ID = 200789, Label = 0
# Index 313: ID = 200793, Label = 0
# Index 314: ID = 200794, Label = 0
# Index 315: ID = 200795, Label = 0
# Index 316: ID = 200797, Label = 0
# Index 317: ID = 200799, Label = 0
# Index 318: ID = 200803, Label = 0
# Index 319: ID = 200805, Label = 0
# Index 320: ID = 200808, Label = 0
# Index 321: ID = 200810, Label = 0
# Index 322: ID = 200817, Label = 0
# Index 323: ID = 200824, Label = 0
# Index 324: ID = 200825, Label = 0
# Index 325: ID = 200826, Label = 0
# Index 326: ID = 200838, Label = 0
# Index 327: ID = 200841, Label = 0
# Index 328: ID = 200846, Label = 0
# Index 329: ID = 200851, Label = 0
# Index 330: ID = 200856, Label = 0
# Index 331: ID = 200859, Label = 0
# Index 332: ID = 200861, Label = 0
# Index 333: ID = 200872, Label = 0
# Index 334: ID = 200873, Label = 0
# Index 335: ID = 200877, Label = 0
# Index 336: ID = 200884, Label = 0
# Index 337: ID = 200890, Label = 0
# Index 338: ID = 200891, Label = 0
# Index 339: ID = 200893, Label = 0
# Index 340: ID = 200899, Label = 0
# Index 341: ID = 200900, Label = 0
# Index 342: ID = 200901, Label = 0
# Index 343: ID = 200902, Label = 0
# Index 344: ID = 200907, Label = 0
# Index 345: ID = 200908, Label = 0
# Index 346: ID = 200912, Label = 0
# Index 347: ID = 200913, Label = 0
# Index 348: ID = 200914, Label = 0
# Index 349: ID = 200916, Label = 0
# Index 350: ID = 200918, Label = 0
# Index 351: ID = 200921, Label = 0
# Index 352: ID = 200922, Label = 0
# Index 353: ID = 200926, Label = 0
# Index 354: ID = 200929, Label = 0
# Index 355: ID = 200930, Label = 0
# Index 356: ID = 200931, Label = 0
# Index 357: ID = 200932, Label = 0
# Index 358: ID = 200934, Label = 0
# Index 359: ID = 200935, Label = 0
# Index 360: ID = 200937, Label = 0
# Index 361: ID = 200938, Label = 0
# Index 362: ID = 200940, Label = 0
# Index 363: ID = 200943, Label = 0
# Index 364: ID = 200944, Label = 0
# Index 365: ID = 200952, Label = 0
# Index 366: ID = 200954, Label = 0
# Index 367: ID = 200960, Label = 0
# Index 368: ID = 200966, Label = 0
# Index 369: ID = 200972, Label = 0
# Index 370: ID = 200973, Label = 0
# Index 371: ID = 200980, Label = 0
# Index 372: ID = 200981, Label = 0
# Index 373: ID = 200982, Label = 0
# Index 374: ID = 200985, Label = 0
# Index 375: ID = 200988, Label = 0
# Index 376: ID = 200989, Label = 0
# Index 377: ID = 200993, Label = 0
# Index 378: ID = 200995, Label = 0
# Index 379: ID = 200998, Label = 0
# Index 380: ID = 200999, Label = 0
# Index 381: ID = 201001, Label = 0
# Index 382: ID = 201003, Label = 0
# Index 383: ID = 201005, Label = 0
# Index 384: ID = 201007, Label = 0
# Index 385: ID = 201008, Label = 0
# Index 386: ID = 201009, Label = 0
# Index 387: ID = 201013, Label = 0
# Index 388: ID = 201015, Label = 0
# Index 389: ID = 201018, Label = 0
# Index 390: ID = 201020, Label = 0
# Index 391: ID = 201025, Label = 0
# Index 392: ID = 201026, Label = 0
# Index 393: ID = 201028, Label = 0
# Index 394: ID = 201029, Label = 0
# Index 395: ID = 201031, Label = 0
# Index 396: ID = 201034, Label = 0
# Index 397: ID = 201037, Label = 0
# Index 398: ID = 201038, Label = 0
# Index 399: ID = 201043, Label = 0
# Index 400: ID = 201045, Label = 0
# Index 401: ID = 201047, Label = 0
# Index 402: ID = 201050, Label = 0
# Index 403: ID = 201052, Label = 0
# Index 404: ID = 201053, Label = 0
# Index 405: ID = 201054, Label = 0
# Index 406: ID = 201062, Label = 0
# Index 407: ID = 201067, Label = 0
# Index 408: ID = 201071, Label = 0
# Index 409: ID = 201073, Label = 0
# Index 410: ID = 201074, Label = 0
# Index 411: ID = 201076, Label = 0
# Index 412: ID = 201078, Label = 0
# Index 413: ID = 201081, Label = 0
# Index 414: ID = 201082, Label = 0
# Index 415: ID = 201083, Label = 0
# Index 416: ID = 201085, Label = 0
# Index 417: ID = 201086, Label = 0
# Index 418: ID = 201087, Label = 0
# Index 419: ID = 201090, Label = 0
# Index 420: ID = 201091, Label = 0
# Index 421: ID = 201092, Label = 0
# Index 422: ID = 201095, Label = 0
# Index 423: ID = 201096, Label = 0
# Index 424: ID = 201098, Label = 0
# Index 425: ID = 201101, Label = 0
# Index 426: ID = 201102, Label = 0
# Index 427: ID = 201106, Label = 0
# Index 428: ID = 201110, Label = 0
# Index 429: ID = 201113, Label = 0
# Index 430: ID = 201116, Label = 0
# Index 431: ID = 201119, Label = 0
# Index 432: ID = 201121, Label = 0
# Index 433: ID = 201125, Label = 0
# Index 434: ID = 201131, Label = 0
# Index 435: ID = 201133, Label = 0
# Index 436: ID = 201136, Label = 0
# Index 437: ID = 201142, Label = 0
# Index 438: ID = 201143, Label = 0
# Index 439: ID = 201145, Label = 0
# Index 440: ID = 201148, Label = 0
# Index 441: ID = 201151, Label = 0
# Index 442: ID = 201152, Label = 0
# Index 443: ID = 201153, Label = 0
# Index 444: ID = 201157, Label = 0
# Index 445: ID = 201162, Label = 0
# Index 446: ID = 201164, Label = 0
# Index 447: ID = 201168, Label = 0
# Index 448: ID = 201169, Label = 0
# Index 449: ID = 201170, Label = 0
# Index 450: ID = 201172, Label = 0
# Index 451: ID = 201173, Label = 0
# Index 452: ID = 201180, Label = 0
# Index 453: ID = 201182, Label = 0
# Index 454: ID = 201186, Label = 0
# Index 455: ID = 201191, Label = 0
# Index 456: ID = 201193, Label = 0
# Index 457: ID = 201197, Label = 0
# Index 458: ID = 201198, Label = 0
# Index 459: ID = 201204, Label = 0
# Index 460: ID = 201206, Label = 0
# Index 461: ID = 201209, Label = 0
# Index 462: ID = 201212, Label = 0
# Index 463: ID = 201214, Label = 0
# Index 464: ID = 201215, Label = 0
# Index 465: ID = 201220, Label = 0
# Index 466: ID = 201226, Label = 0
# Index 467: ID = 201233, Label = 0
# Index 468: ID = 201237, Label = 0
# Index 469: ID = 201239, Label = 0
# Index 470: ID = 201240, Label = 0
# Index 471: ID = 201241, Label = 0
# Index 472: ID = 201243, Label = 0
# Index 473: ID = 201246, Label = 0
# Index 474: ID = 201249, Label = 0
# Index 475: ID = 201250, Label = 0
# Index 476: ID = 201254, Label = 0
# Index 477: ID = 201257, Label = 0
# Index 478: ID = 201263, Label = 0
# Index 479: ID = 201264, Label = 0
# Index 480: ID = 201266, Label = 0
# Index 481: ID = 201268, Label = 0
# Index 482: ID = 201271, Label = 0
# Index 483: ID = 201272, Label = 0
# Index 484: ID = 201274, Label = 0
# Index 485: ID = 201276, Label = 0
# Index 486: ID = 201278, Label = 0
# Index 487: ID = 201281, Label = 0
# Index 488: ID = 201289, Label = 0
# Index 489: ID = 201291, Label = 0
# Index 490: ID = 201295, Label = 0
# Index 491: ID = 201296, Label = 0
# Index 492: ID = 201302, Label = 0
# Index 493: ID = 201303, Label = 0
# Index 494: ID = 201304, Label = 0
# Index 495: ID = 201307, Label = 0
# Index 496: ID = 201308, Label = 0
# Index 497: ID = 201310, Label = 0
# Index 498: ID = 201315, Label = 0
# Index 499: ID = 201317, Label = 0
# Index 500: ID = 201318, Label = 0
# Index 501: ID = 201322, Label = 0
# Index 502: ID = 201324, Label = 0
# Index 503: ID = 201325, Label = 0
# Index 504: ID = 201326, Label = 0
# Index 505: ID = 201328, Label = 0
# Index 506: ID = 201333, Label = 0
# Index 507: ID = 201341, Label = 0
# Index 508: ID = 201343, Label = 0
# Index 509: ID = 201348, Label = 0
# Index 510: ID = 201350, Label = 0
# Index 511: ID = 201352, Label = 0
# Index 512: ID = 201353, Label = 0
# Index 513: ID = 201357, Label = 0
# Index 514: ID = 201358, Label = 0
# Index 515: ID = 201359, Label = 0
# Index 516: ID = 201360, Label = 0
# Index 517: ID = 201361, Label = 0
# Index 518: ID = 201363, Label = 0
# Index 519: ID = 201368, Label = 0
# Index 520: ID = 201370, Label = 0
# Index 521: ID = 201372, Label = 0
# Index 522: ID = 201373, Label = 0
# Index 523: ID = 201376, Label = 0
# Index 524: ID = 201379, Label = 0
# Index 525: ID = 201382, Label = 0
# Index 526: ID = 201387, Label = 0
# Index 527: ID = 201388, Label = 0
# Index 528: ID = 201394, Label = 0
# Index 529: ID = 201397, Label = 0
# Index 530: ID = 201400, Label = 0
# Index 531: ID = 201401, Label = 0
# Index 532: ID = 201405, Label = 0
# Index 533: ID = 201406, Label = 0
# Index 534: ID = 201409, Label = 0
# Index 535: ID = 201415, Label = 0
# Index 536: ID = 201420, Label = 0
# Index 537: ID = 201422, Label = 0
# Index 538: ID = 201427, Label = 0
# Index 539: ID = 201428, Label = 0
# Index 540: ID = 201430, Label = 0
# Index 541: ID = 201431, Label = 0
# Index 542: ID = 201432, Label = 0
# Index 543: ID = 201435, Label = 0
# Index 544: ID = 201437, Label = 0
# Index 545: ID = 201440, Label = 0
# Index 546: ID = 201441, Label = 0
# Index 547: ID = 201442, Label = 0
# Index 548: ID = 201444, Label = 0
# Index 549: ID = 201445, Label = 0
# Index 550: ID = 201449, Label = 0
# Index 551: ID = 201462, Label = 0
# Index 552: ID = 201466, Label = 0
# Index 553: ID = 201468, Label = 0
# Index 554: ID = 201480, Label = 0
# Index 555: ID = 201482, Label = 0
# Index 556: ID = 201484, Label = 0
# Index 557: ID = 201485, Label = 0
# Index 558: ID = 201490, Label = 0
# Index 559: ID = 201492, Label = 0
# Index 560: ID = 201496, Label = 0
# Index 561: ID = 201499, Label = 0
# Index 562: ID = 201501, Label = 0
# Index 563: ID = 201509, Label = 0
# Index 564: ID = 201511, Label = 0
# Index 565: ID = 201515, Label = 0
# Index 566: ID = 201517, Label = 0
# Index 567: ID = 201521, Label = 0
# Index 568: ID = 201523, Label = 0
# Index 569: ID = 201524, Label = 0
# Index 570: ID = 201533, Label = 0
# Index 571: ID = 201535, Label = 0
# Index 572: ID = 201540, Label = 0
# Index 573: ID = 201543, Label = 0
# Index 574: ID = 201544, Label = 0
# Index 575: ID = 201547, Label = 0
# Index 576: ID = 201552, Label = 0
# Index 577: ID = 201553, Label = 0
# Index 578: ID = 201554, Label = 0
# Index 579: ID = 201555, Label = 0
# Index 580: ID = 201559, Label = 0
# Index 581: ID = 201560, Label = 0
# Index 582: ID = 201566, Label = 0
# Index 583: ID = 201567, Label = 0
# Index 584: ID = 201569, Label = 0
# Index 585: ID = 201573, Label = 0
# Index 586: ID = 201578, Label = 0
# Index 587: ID = 201580, Label = 0
# Index 588: ID = 201584, Label = 0
# Index 589: ID = 201585, Label = 0
# Index 590: ID = 201589, Label = 0
# Index 591: ID = 201590, Label = 0
# Index 592: ID = 201594, Label = 0
# Index 593: ID = 201598, Label = 0
# Index 594: ID = 201599, Label = 0
# Index 595: ID = 201603, Label = 0
# Index 596: ID = 201605, Label = 0
# Index 597: ID = 201614, Label = 0
# Index 598: ID = 201619, Label = 0
# Index 599: ID = 201621, Label = 0
# Index 600: ID = 201623, Label = 0
# Index 601: ID = 201624, Label = 0
# Index 602: ID = 201629, Label = 0
# Index 603: ID = 201630, Label = 0
# Index 604: ID = 201633, Label = 0
# Index 605: ID = 201636, Label = 0
# Index 606: ID = 201637, Label = 0
# Index 607: ID = 201642, Label = 0
# Index 608: ID = 201643, Label = 0
# Index 609: ID = 201644, Label = 0
# Index 610: ID = 201645, Label = 0
# Index 611: ID = 201648, Label = 0
# Index 612: ID = 201653, Label = 0
# Index 613: ID = 201656, Label = 0
# Index 614: ID = 201657, Label = 0
# Index 615: ID = 201658, Label = 0
# Index 616: ID = 201659, Label = 0
# Index 617: ID = 201665, Label = 0
# Index 618: ID = 201667, Label = 0
# Index 619: ID = 201668, Label = 0
# Index 620: ID = 201671, Label = 0
# Index 621: ID = 201675, Label = 0
# Index 622: ID = 201680, Label = 0
# Index 623: ID = 201682, Label = 0
# Index 624: ID = 201683, Label = 0
# Index 625: ID = 201689, Label = 0
# Index 626: ID = 201698, Label = 0
# Index 627: ID = 201701, Label = 0
# Index 628: ID = 201702, Label = 0
# Index 629: ID = 201710, Label = 0
# Index 630: ID = 201711, Label = 0
# Index 631: ID = 201713, Label = 0
# Index 632: ID = 201715, Label = 0
# Index 633: ID = 201718, Label = 0
# Index 634: ID = 201719, Label = 0
# Index 635: ID = 201721, Label = 0
# Index 636: ID = 201722, Label = 0
# Index 637: ID = 201726, Label = 0
# Index 638: ID = 201727, Label = 0
# Index 639: ID = 201728, Label = 0
# Index 640: ID = 201731, Label = 0
# Index 641: ID = 201732, Label = 0
# Index 642: ID = 201733, Label = 0
# Index 643: ID = 201735, Label = 0
# Index 644: ID = 201737, Label = 0
# Index 645: ID = 201738, Label = 0
# Index 646: ID = 201739, Label = 0
# Index 647: ID = 201741, Label = 0
# Index 648: ID = 201742, Label = 0
# Index 649: ID = 201746, Label = 0
# Index 650: ID = 201747, Label = 0
# Index 651: ID = 201749, Label = 0
# Index 652: ID = 201751, Label = 0
# Index 653: ID = 201756, Label = 0
# Index 654: ID = 201757, Label = 0
# Index 655: ID = 201761, Label = 0
# Index 656: ID = 201762, Label = 0
# Index 657: ID = 201767, Label = 0
# Index 658: ID = 201768, Label = 0
# Index 659: ID = 201770, Label = 0
# Index 660: ID = 201774, Label = 0
# Index 661: ID = 201785, Label = 0
# Index 662: ID = 201789, Label = 0
# Index 663: ID = 201793, Label = 0
# Index 664: ID = 201794, Label = 0
# Index 665: ID = 201795, Label = 0
# Index 666: ID = 201797, Label = 0
# Index 667: ID = 201810, Label = 0
# Index 668: ID = 201812, Label = 0
# Index 669: ID = 201815, Label = 0
# Index 670: ID = 201816, Label = 0
# Index 671: ID = 201817, Label = 0
# Index 672: ID = 201818, Label = 0
# Index 673: ID = 201820, Label = 0
# Index 674: ID = 201821, Label = 0
# Index 675: ID = 201823, Label = 0
# Index 676: ID = 201824, Label = 0
# Index 677: ID = 201834, Label = 0
# Index 678: ID = 201838, Label = 0
# Index 679: ID = 201840, Label = 0
# Index 680: ID = 201847, Label = 0
# Index 681: ID = 201851, Label = 0
# Index 682: ID = 201852, Label = 0
# Index 683: ID = 201857, Label = 0
# Index 684: ID = 201859, Label = 0
# Index 685: ID = 201864, Label = 0
# Index 686: ID = 201866, Label = 0
# Index 687: ID = 201868, Label = 0
# Index 688: ID = 201869, Label = 0
# Index 689: ID = 201872, Label = 0
# Index 690: ID = 201873, Label = 0
# Index 691: ID = 201876, Label = 0
# Index 692: ID = 201877, Label = 0
# Index 693: ID = 201881, Label = 0
# Index 694: ID = 201882, Label = 0
# Index 695: ID = 201883, Label = 0
# Index 696: ID = 201885, Label = 0
# Index 697: ID = 201891, Label = 0
# Index 698: ID = 201893, Label = 0
# Index 699: ID = 201896, Label = 0
# Index 700: ID = 201897, Label = 0
# Index 701: ID = 201901, Label = 0
# Index 702: ID = 201902, Label = 0
# Index 703: ID = 201903, Label = 0
# Index 704: ID = 201905, Label = 0
# Index 705: ID = 201912, Label = 0
# Index 706: ID = 201913, Label = 0
# Index 707: ID = 201914, Label = 0
# Index 708: ID = 201915, Label = 0
# Index 709: ID = 201920, Label = 0
# Index 710: ID = 201921, Label = 0
# Index 711: ID = 201924, Label = 0
# Index 712: ID = 201925, Label = 0
# Index 713: ID = 201930, Label = 0
# Index 714: ID = 201931, Label = 0
# Index 715: ID = 201933, Label = 0
# Index 716: ID = 201935, Label = 0
# Index 717: ID = 201936, Label = 0
# Index 718: ID = 201939, Label = 0
# Index 719: ID = 201940, Label = 0
# Index 720: ID = 201946, Label = 0
# Index 721: ID = 201947, Label = 0
# Index 722: ID = 201948, Label = 0
# Index 723: ID = 201949, Label = 0
# Index 724: ID = 201951, Label = 0
# Index 725: ID = 201953, Label = 0
# Index 726: ID = 201955, Label = 0
# Index 727: ID = 201956, Label = 0
# Index 728: ID = 201959, Label = 0
# Index 729: ID = 201960, Label = 0
# Index 730: ID = 201961, Label = 0
# Index 731: ID = 201966, Label = 0
# Index 732: ID = 201969, Label = 0
# Index 733: ID = 201970, Label = 0
# Index 734: ID = 201973, Label = 0
# Index 735: ID = 201976, Label = 0
# Index 736: ID = 201977, Label = 0
# Index 737: ID = 201978, Label = 0
# Index 738: ID = 201979, Label = 0
# Index 739: ID = 201982, Label = 0
# Index 740: ID = 201983, Label = 0
# Index 741: ID = 201991, Label = 0
# Index 742: ID = 202006, Label = 0
# Index 743: ID = 202010, Label = 0
# Index 744: ID = 202013, Label = 0
# Index 745: ID = 202015, Label = 0
# Index 746: ID = 202016, Label = 0
# Index 747: ID = 202017, Label = 0
# Index 748: ID = 202019, Label = 0
# Index 749: ID = 202022, Label = 0
# Index 750: ID = 202024, Label = 0
# Index 751: ID = 202025, Label = 0
# Index 752: ID = 202026, Label = 0
# Index 753: ID = 202029, Label = 0
# Index 754: ID = 202030, Label = 0
# Index 755: ID = 202032, Label = 0
# Index 756: ID = 202034, Label = 0
# Index 757: ID = 202036, Label = 0
# Index 758: ID = 202037, Label = 0
# Index 759: ID = 202042, Label = 0
# Index 760: ID = 202045, Label = 0
# Index 761: ID = 202049, Label = 0
# Index 762: ID = 202053, Label = 0
# Index 763: ID = 202055, Label = 0
# Index 764: ID = 202057, Label = 0
# Index 765: ID = 202058, Label = 0
# Index 766: ID = 202060, Label = 0
# Index 767: ID = 202063, Label = 0
# Index 768: ID = 202065, Label = 0
# Index 769: ID = 202068, Label = 0
# Index 770: ID = 202069, Label = 0
# Index 771: ID = 202070, Label = 0
# Index 772: ID = 202071, Label = 0
# Index 773: ID = 202074, Label = 0
# Index 774: ID = 202079, Label = 0
# Index 775: ID = 202088, Label = 0
# Index 776: ID = 202089, Label = 0
# Index 777: ID = 202091, Label = 0
# Index 778: ID = 202092, Label = 0
# Index 779: ID = 202094, Label = 0
# Index 780: ID = 202099, Label = 0
# Index 781: ID = 202101, Label = 0
# Index 782: ID = 202114, Label = 0
# Index 783: ID = 202115, Label = 0
# Index 784: ID = 202119, Label = 0
# Index 785: ID = 202122, Label = 0
# Index 786: ID = 202127, Label = 0
# Index 787: ID = 202128, Label = 0
# Index 788: ID = 202129, Label = 0
# Index 789: ID = 202132, Label = 0
# Index 790: ID = 202135, Label = 0
# Index 791: ID = 202137, Label = 0
# Index 792: ID = 202139, Label = 0
# Index 793: ID = 202142, Label = 0
# Index 794: ID = 202148, Label = 0
# Index 795: ID = 202151, Label = 0
# Index 796: ID = 202152, Label = 0
# Index 797: ID = 202155, Label = 0
# Index 798: ID = 202161, Label = 0
# Index 799: ID = 202163, Label = 0
# Index 800: ID = 202164, Label = 0
# Index 801: ID = 202166, Label = 0
# Index 802: ID = 202171, Label = 0
# Index 803: ID = 202174, Label = 0
# Index 804: ID = 202178, Label = 0
# Index 805: ID = 202181, Label = 0
# Index 806: ID = 202182, Label = 0
# Index 807: ID = 202183, Label = 0
# Index 808: ID = 202191, Label = 0
# Index 809: ID = 202193, Label = 0
# Index 810: ID = 202196, Label = 0
# Index 811: ID = 202197, Label = 0
# Index 812: ID = 202202, Label = 0
# Index 813: ID = 202203, Label = 0
# Index 814: ID = 202205, Label = 0
# Index 815: ID = 202206, Label = 0
# Index 816: ID = 202207, Label = 0
# Index 817: ID = 202209, Label = 0
# Index 818: ID = 202210, Label = 0
# Index 819: ID = 202211, Label = 0
# Index 820: ID = 202212, Label = 0
# Index 821: ID = 202214, Label = 0
# Index 822: ID = 202223, Label = 0
# Index 823: ID = 202224, Label = 0
# Index 824: ID = 202227, Label = 0
# Index 825: ID = 202230, Label = 0
# Index 826: ID = 202234, Label = 0
# Index 827: ID = 202242, Label = 0
# Index 828: ID = 202246, Label = 0
# Index 829: ID = 202247, Label = 0
# Index 830: ID = 202251, Label = 0
# Index 831: ID = 202252, Label = 0
# Index 832: ID = 202253, Label = 0
# Index 833: ID = 202255, Label = 0
# Index 834: ID = 202263, Label = 0
# Index 835: ID = 202265, Label = 0
# Index 836: ID = 202266, Label = 0
# Index 837: ID = 202268, Label = 0
# Index 838: ID = 202270, Label = 0
# Index 839: ID = 202279, Label = 0
# Index 840: ID = 202280, Label = 0
# Index 841: ID = 202286, Label = 0
# Index 842: ID = 202287, Label = 0
# Index 843: ID = 202289, Label = 0
# Index 844: ID = 202291, Label = 0
# Index 845: ID = 202293, Label = 0
# Index 846: ID = 202297, Label = 0
# Index 847: ID = 202298, Label = 0
# Index 848: ID = 202299, Label = 0
# Index 849: ID = 202301, Label = 0
# Index 850: ID = 202305, Label = 0
# Index 851: ID = 202308, Label = 0
# Index 852: ID = 202309, Label = 0
# Index 853: ID = 202322, Label = 0
# Index 854: ID = 202324, Label = 0
# Index 855: ID = 202326, Label = 0
# Index 856: ID = 202327, Label = 0
# Index 857: ID = 202333, Label = 0
# Index 858: ID = 202334, Label = 0
# Index 859: ID = 202338, Label = 0
# Index 860: ID = 202348, Label = 0
# Index 861: ID = 202349, Label = 0
# Index 862: ID = 202350, Label = 0
# Index 863: ID = 202351, Label = 0
# Index 864: ID = 202352, Label = 0
# Index 865: ID = 202354, Label = 0
# Index 866: ID = 202357, Label = 0
# Index 867: ID = 202360, Label = 0
# Index 868: ID = 202362, Label = 0
# Index 869: ID = 202365, Label = 0
# Index 870: ID = 202368, Label = 0
# Index 871: ID = 202371, Label = 0
# Index 872: ID = 202373, Label = 0
# Index 873: ID = 202380, Label = 0
# Index 874: ID = 202381, Label = 0
# Index 875: ID = 202382, Label = 0
# Index 876: ID = 202383, Label = 0
# Index 877: ID = 202385, Label = 0
# Index 878: ID = 202386, Label = 0
# Index 879: ID = 202395, Label = 0
# Index 880: ID = 202396, Label = 0
# Index 881: ID = 202400, Label = 0
# Index 882: ID = 202403, Label = 0
# Index 883: ID = 202404, Label = 0
# Index 884: ID = 202405, Label = 0
# Index 885: ID = 202407, Label = 0
# Index 886: ID = 202412, Label = 0
# Index 887: ID = 202413, Label = 0
# Index 888: ID = 202414, Label = 0
# Index 889: ID = 202415, Label = 0
# Index 890: ID = 202417, Label = 0
# Index 891: ID = 202419, Label = 0
# Index 892: ID = 202422, Label = 0
# Index 893: ID = 202426, Label = 0
# Index 894: ID = 202428, Label = 0
# Index 895: ID = 202431, Label = 0
# Index 896: ID = 202432, Label = 0
# Index 897: ID = 202433, Label = 0
# Index 898: ID = 202437, Label = 0
# Index 899: ID = 202439, Label = 0
# Index 900: ID = 202444, Label = 0
# Index 901: ID = 202445, Label = 0
# Index 902: ID = 202447, Label = 0
# Index 903: ID = 202448, Label = 0
# Index 904: ID = 202453, Label = 0
# Index 905: ID = 202458, Label = 0
# Index 906: ID = 202464, Label = 0
# Index 907: ID = 202465, Label = 0
# Index 908: ID = 202467, Label = 0
# Index 909: ID = 202468, Label = 0
# Index 910: ID = 202476, Label = 0
# Index 911: ID = 202478, Label = 0
# Index 912: ID = 202480, Label = 0
# Index 913: ID = 202481, Label = 0
# Index 914: ID = 202482, Label = 0
# Index 915: ID = 202485, Label = 0
# Index 916: ID = 202486, Label = 0
# Index 917: ID = 202488, Label = 0
# Index 918: ID = 202489, Label = 0
# Index 919: ID = 202492, Label = 0
# Index 920: ID = 202493, Label = 0
# Index 921: ID = 202496, Label = 0
# Index 922: ID = 202499, Label = 0
# Index 923: ID = 202500, Label = 0
# Index 924: ID = 202503, Label = 0
# Index 925: ID = 202505, Label = 0
# Index 926: ID = 202507, Label = 0
# Index 927: ID = 202509, Label = 0
# Index 928: ID = 202510, Label = 0
# Index 929: ID = 202511, Label = 0
# Index 930: ID = 202513, Label = 0
# Index 931: ID = 202515, Label = 0
# Index 932: ID = 202516, Label = 0
# Index 933: ID = 202519, Label = 0
# Index 934: ID = 202524, Label = 0
# Index 935: ID = 202527, Label = 0
# Index 936: ID = 202532, Label = 0
# Index 937: ID = 202534, Label = 0
# Index 938: ID = 202536, Label = 0
# Index 939: ID = 202539, Label = 0
# Index 940: ID = 202541, Label = 0
# Index 941: ID = 202545, Label = 0
# Index 942: ID = 202546, Label = 0
# Index 943: ID = 202547, Label = 0
# Index 944: ID = 202548, Label = 0
# Index 945: ID = 202554, Label = 0
# Index 946: ID = 202555, Label = 0
# Index 947: ID = 202556, Label = 0
# Index 948: ID = 202557, Label = 0
# Index 949: ID = 202558, Label = 0
# Index 950: ID = 202559, Label = 0
# Index 951: ID = 202564, Label = 0
# Index 952: ID = 202565, Label = 0
# Index 953: ID = 202566, Label = 0
# Index 954: ID = 202567, Label = 0
# Index 955: ID = 202570, Label = 0
# Index 956: ID = 202571, Label = 0
# Index 957: ID = 202572, Label = 0
# Index 958: ID = 202584, Label = 0
# Index 959: ID = 202586, Label = 0
# Index 960: ID = 202587, Label = 0
# Index 961: ID = 202588, Label = 0
# Index 962: ID = 202594, Label = 0
# Index 963: ID = 202595, Label = 0
# Index 964: ID = 202600, Label = 0
# Index 965: ID = 202603, Label = 0
# Index 966: ID = 202605, Label = 0
# Index 967: ID = 202607, Label = 0
# Index 968: ID = 202610, Label = 0
# Index 969: ID = 202612, Label = 0
# Index 970: ID = 202613, Label = 0
# Index 971: ID = 202614, Label = 0
# Index 972: ID = 202620, Label = 0
# Index 973: ID = 202621, Label = 0
# Index 974: ID = 202622, Label = 0
# Index 975: ID = 202623, Label = 0
# Index 976: ID = 202624, Label = 0
# Index 977: ID = 202625, Label = 0
# Index 978: ID = 202629, Label = 0
# Index 979: ID = 202633, Label = 0
# Index 980: ID = 202634, Label = 0
# Index 981: ID = 202635, Label = 0
# Index 982: ID = 202641, Label = 0
# Index 983: ID = 202642, Label = 0
# Index 984: ID = 202644, Label = 0
# Index 985: ID = 202646, Label = 0
# Index 986: ID = 202650, Label = 0
# Index 987: ID = 202651, Label = 0
# Index 988: ID = 202652, Label = 0
# Index 989: ID = 202660, Label = 0
# Index 990: ID = 202662, Label = 0
# Index 991: ID = 202668, Label = 0
# Index 992: ID = 202669, Label = 0
# Index 993: ID = 202675, Label = 0
# Index 994: ID = 202676, Label = 0
# Index 995: ID = 202682, Label = 0
# Index 996: ID = 202683, Label = 0
# Index 997: ID = 202684, Label = 0
# Index 998: ID = 202690, Label = 0
# Index 999: ID = 202691, Label = 0
# Index 1000: ID = 202692, Label = 0
# Index 1001: ID = 202694, Label = 0
# Index 1002: ID = 202695, Label = 0
# Index 1003: ID = 202700, Label = 0
# Index 1004: ID = 202703, Label = 0
# Index 1005: ID = 202706, Label = 0
# Index 1006: ID = 202711, Label = 0
# Index 1007: ID = 202712, Label = 0
# Index 1008: ID = 202713, Label = 0
# Index 1009: ID = 202714, Label = 0
# Index 1010: ID = 202715, Label = 0
# Index 1011: ID = 202716, Label = 0
# Index 1012: ID = 202717, Label = 0
# Index 1013: ID = 202722, Label = 0
# Index 1014: ID = 202724, Label = 0
# Index 1015: ID = 202726, Label = 0
# Index 1016: ID = 202727, Label = 0
# Index 1017: ID = 202739, Label = 0
# Index 1018: ID = 202741, Label = 0
# Index 1019: ID = 202742, Label = 0
# Index 1020: ID = 202747, Label = 0
# Index 1021: ID = 202756, Label = 0
# Index 1022: ID = 202758, Label = 0
# Index 1023: ID = 202759, Label = 0
# Index 1024: ID = 202761, Label = 0
# Index 1025: ID = 202762, Label = 0
# Index 1026: ID = 202766, Label = 0
# Index 1027: ID = 202768, Label = 0
# Index 1028: ID = 202774, Label = 0
# Index 1029: ID = 202780, Label = 0
# Index 1030: ID = 202781, Label = 0
# Index 1031: ID = 202782, Label = 0
# Index 1032: ID = 202783, Label = 0
# Index 1033: ID = 202784, Label = 0
# Index 1034: ID = 202786, Label = 0
# Index 1035: ID = 202787, Label = 0
# Index 1036: ID = 202790, Label = 0
# Index 1037: ID = 202791, Label = 0
# Index 1038: ID = 202795, Label = 0
# Index 1039: ID = 202798, Label = 0
# Index 1040: ID = 202799, Label = 0
# Index 1041: ID = 202801, Label = 0
# Index 1042: ID = 202802, Label = 0
# Index 1043: ID = 202803, Label = 0
# Index 1044: ID = 202805, Label = 0
# Index 1045: ID = 202806, Label = 0
# Index 1046: ID = 202811, Label = 0
# Index 1047: ID = 202816, Label = 0
# Index 1048: ID = 202818, Label = 0
# Index 1049: ID = 202823, Label = 0
# Index 1050: ID = 202827, Label = 0
# Index 1051: ID = 202828, Label = 0
# Index 1052: ID = 202829, Label = 0
# Index 1053: ID = 202831, Label = 0
# Index 1054: ID = 202833, Label = 0
# Index 1055: ID = 202837, Label = 0
# Index 1056: ID = 202838, Label = 0
# Index 1057: ID = 202841, Label = 0
# Index 1058: ID = 202842, Label = 0
# Index 1059: ID = 202848, Label = 0
# Index 1060: ID = 202852, Label = 0
# Index 1061: ID = 202853, Label = 0
# Index 1062: ID = 202857, Label = 0
# Index 1063: ID = 202859, Label = 0
# Index 1064: ID = 202865, Label = 0
# Index 1065: ID = 202867, Label = 0
# Index 1066: ID = 202869, Label = 0
# Index 1067: ID = 202872, Label = 0
# Index 1068: ID = 202874, Label = 0
# Index 1069: ID = 202877, Label = 0
# Index 1070: ID = 202885, Label = 0
# Index 1071: ID = 202887, Label = 0
# Index 1072: ID = 202890, Label = 0
# Index 1073: ID = 202892, Label = 0
# Index 1074: ID = 202894, Label = 0
# Index 1075: ID = 202898, Label = 0
# Index 1076: ID = 202899, Label = 0
# Index 1077: ID = 202904, Label = 0
# Index 1078: ID = 202907, Label = 0
# Index 1079: ID = 202909, Label = 0
# Index 1080: ID = 202912, Label = 0
# Index 1081: ID = 202913, Label = 0
# Index 1082: ID = 202914, Label = 0
# Index 1083: ID = 202916, Label = 0
# Index 1084: ID = 202918, Label = 0
# Index 1085: ID = 202920, Label = 0
# Index 1086: ID = 202921, Label = 0
# Index 1087: ID = 202924, Label = 0
# Index 1088: ID = 202928, Label = 0
# Index 1089: ID = 202929, Label = 0
# Index 1090: ID = 202932, Label = 0
# Index 1091: ID = 202933, Label = 0
# Index 1092: ID = 202935, Label = 0
# Index 1093: ID = 202937, Label = 0
# Index 1094: ID = 202938, Label = 0
# Index 1095: ID = 202943, Label = 0
# Index 1096: ID = 202945, Label = 0
# Index 1097: ID = 202951, Label = 0
# Index 1098: ID = 202954, Label = 0
# Index 1099: ID = 202955, Label = 0
# Index 1100: ID = 202956, Label = 0
# Index 1101: ID = 202957, Label = 0
# Index 1102: ID = 202958, Label = 0
# Index 1103: ID = 202960, Label = 0
# Index 1104: ID = 202963, Label = 0
# Index 1105: ID = 202964, Label = 0
# Index 1106: ID = 202965, Label = 0
# Index 1107: ID = 202967, Label = 0
# Index 1108: ID = 202973, Label = 0
# Index 1109: ID = 202976, Label = 0
# Index 1110: ID = 202980, Label = 0
# Index 1111: ID = 202981, Label = 0
# Index 1112: ID = 202983, Label = 0
# Index 1113: ID = 202985, Label = 0
# Index 1114: ID = 202989, Label = 0
# Index 1115: ID = 202993, Label = 0
# Index 1116: ID = 202994, Label = 0
# Index 1117: ID = 202996, Label = 0
# Index 1118: ID = 202997, Label = 0
# Index 1119: ID = 203003, Label = 0
# Index 1120: ID = 203004, Label = 0
# Index 1121: ID = 203005, Label = 0
# Index 1122: ID = 203008, Label = 0
# Index 1123: ID = 203009, Label = 0
# Index 1124: ID = 203011, Label = 0
# Index 1125: ID = 203013, Label = 0
# Index 1126: ID = 203018, Label = 0
# Index 1127: ID = 203022, Label = 0
# Index 1128: ID = 203028, Label = 0
# Index 1129: ID = 203029, Label = 0
# Index 1130: ID = 203032, Label = 0
# Index 1131: ID = 203040, Label = 0
# Index 1132: ID = 203045, Label = 0
# Index 1133: ID = 203046, Label = 0
# Index 1134: ID = 203053, Label = 0
# Index 1135: ID = 203055, Label = 0
# Index 1136: ID = 203061, Label = 0
# Index 1137: ID = 203062, Label = 0
# Index 1138: ID = 203065, Label = 0
# Index 1139: ID = 203071, Label = 0
# Index 1140: ID = 203074, Label = 0
# Index 1141: ID = 203075, Label = 0
# Index 1142: ID = 203077, Label = 0
# Index 1143: ID = 203079, Label = 0
# Index 1144: ID = 203080, Label = 0
# Index 1145: ID = 203082, Label = 0
# Index 1146: ID = 203085, Label = 0
# Index 1147: ID = 203093, Label = 0
# Index 1148: ID = 203096, Label = 0
# Index 1149: ID = 203098, Label = 0
# Index 1150: ID = 203099, Label = 0
# Index 1151: ID = 203101, Label = 0
# Index 1152: ID = 203105, Label = 0
# Index 1153: ID = 203108, Label = 0
# Index 1154: ID = 203113, Label = 0
# Index 1155: ID = 203118, Label = 0
# Index 1156: ID = 203119, Label = 0
# Index 1157: ID = 203125, Label = 0
# Index 1158: ID = 203126, Label = 0
# Index 1159: ID = 203127, Label = 0
# Index 1160: ID = 203129, Label = 0
# Index 1161: ID = 203133, Label = 0
# Index 1162: ID = 203134, Label = 0
# Index 1163: ID = 203143, Label = 0
# Index 1164: ID = 203146, Label = 0
# Index 1165: ID = 203149, Label = 0
# Index 1166: ID = 203150, Label = 0
# Index 1167: ID = 203154, Label = 0
# Index 1168: ID = 203155, Label = 0
# Index 1169: ID = 203157, Label = 0
# Index 1170: ID = 203159, Label = 0
# Index 1171: ID = 203161, Label = 0
# Index 1172: ID = 203165, Label = 0
# Index 1173: ID = 203166, Label = 0
# Index 1174: ID = 203168, Label = 0
# Index 1175: ID = 203171, Label = 0
# Index 1176: ID = 203175, Label = 0
# Index 1177: ID = 203176, Label = 0
# Index 1178: ID = 203177, Label = 0
# Index 1179: ID = 203178, Label = 0
# Index 1180: ID = 203181, Label = 0
# Index 1181: ID = 203187, Label = 0
# Index 1182: ID = 203191, Label = 0
# Index 1183: ID = 203192, Label = 0
# Index 1184: ID = 203193, Label = 0
# Index 1185: ID = 203197, Label = 0
# Index 1186: ID = 203198, Label = 0
# Index 1187: ID = 203201, Label = 0
# Index 1188: ID = 203203, Label = 0
# Index 1189: ID = 203207, Label = 0
# Index 1190: ID = 203209, Label = 0
# Index 1191: ID = 203210, Label = 0
# Index 1192: ID = 203212, Label = 0
# Index 1193: ID = 203217, Label = 0
# Index 1194: ID = 203223, Label = 0
# Index 1195: ID = 203225, Label = 0
# Index 1196: ID = 203227, Label = 0
# Index 1197: ID = 203232, Label = 0
# Index 1198: ID = 203236, Label = 0
# Index 1199: ID = 203237, Label = 0
# Index 1200: ID = 203245, Label = 0
# Index 1201: ID = 203246, Label = 0
# Index 1202: ID = 203247, Label = 0
# Index 1203: ID = 203248, Label = 0
# Index 1204: ID = 203251, Label = 0
# Index 1205: ID = 203252, Label = 0
# Index 1206: ID = 203253, Label = 0
# Index 1207: ID = 203254, Label = 0
# Index 1208: ID = 203257, Label = 0
# Index 1209: ID = 203260, Label = 0
# Index 1210: ID = 203266, Label = 0
# Index 1211: ID = 203269, Label = 0
# Index 1212: ID = 203274, Label = 0
# Index 1213: ID = 203277, Label = 0
# Index 1214: ID = 203284, Label = 0
# Index 1215: ID = 203286, Label = 0
# Index 1216: ID = 203287, Label = 0
# Index 1217: ID = 203289, Label = 0
# Index 1218: ID = 203292, Label = 0
# Index 1219: ID = 203293, Label = 0
# Index 1220: ID = 203295, Label = 0
# Index 1221: ID = 203296, Label = 0
# Index 1222: ID = 203298, Label = 0
# Index 1223: ID = 203299, Label = 0
# Index 1224: ID = 203303, Label = 0
# Index 1225: ID = 203304, Label = 0
# Index 1226: ID = 203306, Label = 0
# Index 1227: ID = 203308, Label = 0
# Index 1228: ID = 203312, Label = 0
# Index 1229: ID = 203313, Label = 0
# Index 1230: ID = 203315, Label = 0
# Index 1231: ID = 203320, Label = 0
# Index 1232: ID = 203325, Label = 0
# Index 1233: ID = 203327, Label = 0
# Index 1234: ID = 203328, Label = 0
# Index 1235: ID = 203330, Label = 0
# Index 1236: ID = 203331, Label = 0
# Index 1237: ID = 203333, Label = 0
# Index 1238: ID = 203335, Label = 0
# Index 1239: ID = 203338, Label = 0
# Index 1240: ID = 203344, Label = 0
# Index 1241: ID = 203348, Label = 0
# Index 1242: ID = 203349, Label = 0
# Index 1243: ID = 203353, Label = 0
# Index 1244: ID = 203354, Label = 0
# Index 1245: ID = 203355, Label = 0
# Index 1246: ID = 203356, Label = 0
# Index 1247: ID = 203363, Label = 0
# Index 1248: ID = 203364, Label = 0
# Index 1249: ID = 203369, Label = 0
# Index 1250: ID = 203374, Label = 0
# Index 1251: ID = 203377, Label = 0
# Index 1252: ID = 203383, Label = 0
# Index 1253: ID = 203388, Label = 0
# Index 1254: ID = 203389, Label = 0
# Index 1255: ID = 203390, Label = 0
# Index 1256: ID = 203394, Label = 0
# Index 1257: ID = 203395, Label = 0
# Index 1258: ID = 203397, Label = 0
# Index 1259: ID = 203401, Label = 0
# Index 1260: ID = 203402, Label = 0
# Index 1261: ID = 203403, Label = 0
# Index 1262: ID = 203405, Label = 0
# Index 1263: ID = 203407, Label = 0
# Index 1264: ID = 203410, Label = 0
# Index 1265: ID = 203411, Label = 0
# Index 1266: ID = 203416, Label = 0
# Index 1267: ID = 203427, Label = 0
# Index 1268: ID = 203429, Label = 0
# Index 1269: ID = 203430, Label = 0
# Index 1270: ID = 203431, Label = 0
# Index 1271: ID = 203435, Label = 0
# Index 1272: ID = 203436, Label = 0
# Index 1273: ID = 203440, Label = 0
# Index 1274: ID = 203449, Label = 0
# Index 1275: ID = 203451, Label = 0
# Index 1276: ID = 203453, Label = 0
# Index 1277: ID = 203455, Label = 0
# Index 1278: ID = 203459, Label = 0
# Index 1279: ID = 203460, Label = 0
# Index 1280: ID = 203461, Label = 0
# Index 1281: ID = 203464, Label = 0
# Index 1282: ID = 203467, Label = 0
# Index 1283: ID = 203468, Label = 0
# Index 1284: ID = 203469, Label = 0
# Index 1285: ID = 203473, Label = 0
# Index 1286: ID = 203476, Label = 0
# Index 1287: ID = 203478, Label = 0
# Index 1288: ID = 203482, Label = 0
# Index 1289: ID = 203487, Label = 0
# Index 1290: ID = 203490, Label = 0
# Index 1291: ID = 203493, Label = 0
# Index 1292: ID = 203500, Label = 0
# Index 1293: ID = 203501, Label = 0
# Index 1294: ID = 203503, Label = 0
# Index 1295: ID = 203504, Label = 0
# Index 1296: ID = 203506, Label = 0
# Index 1297: ID = 203511, Label = 0
# Index 1298: ID = 203514, Label = 0
# Index 1299: ID = 203518, Label = 0
# Index 1300: ID = 203523, Label = 0
# Index 1301: ID = 203528, Label = 0
# Index 1302: ID = 203529, Label = 0
# Index 1303: ID = 203532, Label = 0
# Index 1304: ID = 203537, Label = 0
# Index 1305: ID = 203538, Label = 0
# Index 1306: ID = 203539, Label = 0
# Index 1307: ID = 203540, Label = 0
# Index 1308: ID = 203541, Label = 0
# Index 1309: ID = 203542, Label = 0
# Index 1310: ID = 203543, Label = 0
# Index 1311: ID = 203546, Label = 0
# Index 1312: ID = 203553, Label = 0
# Index 1313: ID = 203554, Label = 0
# Index 1314: ID = 203556, Label = 0
# Index 1315: ID = 203559, Label = 0
# Index 1316: ID = 203564, Label = 0
# Index 1317: ID = 203567, Label = 0
# Index 1318: ID = 203568, Label = 0
# Index 1319: ID = 203570, Label = 0
# Index 1320: ID = 203571, Label = 0
# Index 1321: ID = 203573, Label = 0
# Index 1322: ID = 203574, Label = 0
# Index 1323: ID = 203577, Label = 0
# Index 1324: ID = 203579, Label = 0
# Index 1325: ID = 203583, Label = 0
# Index 1326: ID = 203587, Label = 0
# Index 1327: ID = 203589, Label = 0
# Index 1328: ID = 203590, Label = 0
# Index 1329: ID = 203593, Label = 0
# Index 1330: ID = 203596, Label = 0
# Index 1331: ID = 203597, Label = 0
# Index 1332: ID = 203601, Label = 0
# Index 1333: ID = 203602, Label = 0
# Index 1334: ID = 203603, Label = 0
# Index 1335: ID = 203604, Label = 0
# Index 1336: ID = 203618, Label = 0
# Index 1337: ID = 203622, Label = 0
# Index 1338: ID = 203624, Label = 0
# Index 1339: ID = 203625, Label = 0
# Index 1340: ID = 203626, Label = 0
# Index 1341: ID = 203627, Label = 0
# Index 1342: ID = 203633, Label = 0
# Index 1343: ID = 203637, Label = 0
# Index 1344: ID = 203640, Label = 0
# Index 1345: ID = 203641, Label = 0
# Index 1346: ID = 203643, Label = 0
# Index 1347: ID = 203648, Label = 0
# Index 1348: ID = 203650, Label = 0
# Index 1349: ID = 203653, Label = 0
# Index 1350: ID = 203656, Label = 0
# Index 1351: ID = 203664, Label = 0
# Index 1352: ID = 203665, Label = 0
# Index 1353: ID = 203667, Label = 0
# Index 1354: ID = 203668, Label = 0
# Index 1355: ID = 203673, Label = 0
# Index 1356: ID = 203674, Label = 0
# Index 1357: ID = 203676, Label = 0
# Index 1358: ID = 203678, Label = 0
# Index 1359: ID = 203683, Label = 0
# Index 1360: ID = 203687, Label = 0
# Index 1361: ID = 203692, Label = 0
# Index 1362: ID = 203694, Label = 0
# Unique IDs: 35781
# Unique Labels: 1
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-73-3ebd9fb7863d> in <cell line: 6>()
#      18
#      19     # Exit the code if there is a mismatch to prevent further errors
# ---> 20     raise ValueError("Cannot proceed due to mismatched lengths.")
#      21 else:
#      22     print("No length mismatch found.")
#
# ValueError: Cannot proceed due to mismatched lengths.

# %%
# Aggregating each sequence by taking the mean across the time dimension
# Ensure that features like 'icustay_id', 'aki_stage', 'age', and binary features (F, M, ethnicity columns) are preserved and not averaged
aggregated_train_data = []
aggregated_test_data = []
aggregated_validation_data = []

# Define columns to preserve (not average)
preserve_columns = ['icustay_id', 'aki_stage', 'F', 'M', 'asian', 'black',
                    'hispanic', 'native', 'other', 'unknown', 'white', 'sedative', 'vasopressor', 'vent' ]

# Get the indices of columns to preserve
preserve_indices = [train.columns.get_loc(col) for col in preserve_columns]

for seq in train_sequences:
    # Preserve the first occurrence of categorical and identifier columns
    preserved_values = seq[0, preserve_indices]
    # Aggregate the rest by taking the mean
    aggregated_values = np.mean(np.delete(seq, preserve_indices, axis=1), axis=0)
    # Combine preserved values and aggregated values
    combined_values = np.concatenate([preserved_values, aggregated_values])
    aggregated_train_data.append(combined_values)

for seq in test_sequences:
    preserved_values = seq[0, preserve_indices]
    aggregated_values = np.mean(np.delete(seq, preserve_indices, axis=1), axis=0)
    combined_values = np.concatenate([preserved_values, aggregated_values])
    aggregated_test_data.append(combined_values)

for seq in validation_sequences:
    preserved_values = seq[0, preserve_indices]
    aggregated_values = np.mean(np.delete(seq, preserve_indices, axis=1), axis=0)
    combined_values = np.concatenate([preserved_values, aggregated_values])
    aggregated_validation_data.append(combined_values)

# Convert lists to numpy arrays
X_train_agg = np.array(aggregated_train_data)
X_test_agg = np.array(aggregated_test_data)
X_validation_agg = np.array(aggregated_validation_data)

# Print the shape of the aggregated arrays
print(f"Shape of aggregated training data: {X_train_agg.shape}")
print(f"Shape of aggregated test data: {X_test_agg.shape}")
print(f"Shape of aggregated validation data: {X_validation_agg.shape}")
# Out:
# Shape of aggregated training data: (37802, 34)
# Shape of aggregated test data: (4724, 34)
# Shape of aggregated validation data: (4724, 34)

# %%
print(feature_names)
# Out:
# ['Anion gap', 'Bicarbonate', 'Blood Urea Nitrogen', 'Chloride', 'Creatinine', 'Diastolic BP', 'Glucose', 'Heart rate', 'Hematocrit', 'Hemoglobin', 'Potassium', 'Respiratory rate', 'Sodium', 'Oxygen saturation', 'Systolic BP', 'Urine output 12h', 'Urine output 24h', 'Urine output 6h', 'White cell count', 'Sedative', 'Vasopressor', 'Ventilation', 'Age', 'Female gender', 'Male gender', 'Asian ethnicity', 'Black ethnicity', 'Hispanic ethnicity', 'Native american', 'Other ethnicity', 'Ethnicity unknown', 'White ethnicity']

# %%
import pandas as pd
import numpy as np

# Assuming X_train_agg, X_test_agg, X_validation_agg, y_train, y_test, and y_validation are already defined
# and that X_train_agg, X_test_agg, X_validation_agg are numpy arrays
# and that y_train, y_test, y_validation are also numpy arrays

# Step 4: Define feature names including 'icustay_id' and the preserved columns
feature_names_with_id = [
    'icustay_id',         # Identifier
    'aki_stage',          # Target label
    'F', 'M',             # Gender binary features
    'asian', 'black', 'hispanic', 'native', 'other', 'unknown', 'white',  # Ethnicity binary features
    'sedative', 'vasopressor', 'vent',  # Categorical medical interventions
    'aniongap_avg', 'bicarbonate_avg', 'bun_avg', 'chloride_avg', 'creat',
    'diasbp_mean', 'glucose_avg', 'heartrate_mean', 'hematocrit_avg',
    'hemoglobin_avg', 'potassium_avg', 'resprate_mean', 'sodium_avg',
    'spo2_mean', 'sysbp_mean', 'uo_rt_12hr', 'uo_rt_24hr', 'uo_rt_6hr',
    'wbc_avg', 'age'  # Numeric features
]

# Convert the numpy arrays back to pandas DataFrames
X_train = pd.DataFrame(X_train_agg, columns=feature_names_with_id)
X_test = pd.DataFrame(X_test_agg, columns=feature_names_with_id)
X_validation = pd.DataFrame(X_validation_agg, columns=feature_names_with_id)

# Remove 'icustay_id' from the DataFrames
X_train = X_train.drop(['icustay_id'], axis=1)
X_test = X_test.drop(['icustay_id'], axis=1)
X_validation = X_validation.drop(['icustay_id'], axis=1)

# Save the combined dataset with 'icustay_id' to 'final_dataset.csv'
final_dataset = pd.concat([X_train, X_test, X_validation], ignore_index=True)
final_dataset.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/final_dataset_ord.csv', index=False)
# final_dataset.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/final_dataset_final.csv', index=False)
# final_dataset.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/final_dataset_raw.csv', index=False)


# Explicitly identify the index of the 'aki_stage' column
aki_stage_index = list(train.columns).index('aki_stage')

# Extract the labels from the correct 'aki_stage' column
y_train = X_train_agg[:, aki_stage_index]
y_test = X_test_agg[:, aki_stage_index]
y_validation = X_validation_agg[:, aki_stage_index]

# Convert the labels to DataFrames
y_train = pd.DataFrame(y_train.reshape(-1, 1), columns=['aki_stage'])
y_test = pd.DataFrame(y_test.reshape(-1, 1), columns=['aki_stage'])
y_validation = pd.DataFrame(y_validation.reshape(-1, 1), columns=['aki_stage'])

# Remove 'icustay_id' from the DataFrames
X_train = X_train.drop(['aki_stage'], axis=1)
X_test = X_test.drop(['aki_stage'], axis=1)
X_validation = X_validation.drop(['aki_stage'], axis=1)

(X_train.shape, y_train.shape, X_test.shape, y_test.shape, X_validation.shape, y_validation.shape)
# Out:
# ((37802, 32), (37802, 1), (4724, 32), (4724, 1), (4724, 32), (4724, 1))

# %%
import pandas as pd
import numpy as np

# Assuming X_train_flattened, X_test_flattened, X_validation_flattened are the flattened data arrays
# and y_train, y_test, y_validation contain the aki_stage values

# Define the original column names including 'icustay_id' and 'aki_stage'
feature_names_with_id = [
    'icustay_id',         # Identifier
    'aki_stage',          # Target label
    'F', 'M',             # Gender binary features
    'asian', 'black', 'hispanic', 'native', 'other', 'unknown', 'white',  # Ethnicity binary features
    'sedative', 'vasopressor', 'vent',  # Categorical medical interventions
    'aniongap_avg', 'bicarbonate_avg', 'bun_avg', 'chloride_avg', 'creat',
    'diasbp_mean', 'glucose_avg', 'heartrate_mean', 'hematocrit_avg',
    'hemoglobin_avg', 'potassium_avg', 'resprate_mean', 'sodium_avg',
    'spo2_mean', 'sysbp_mean', 'uo_rt_12hr', 'uo_rt_24hr', 'uo_rt_6hr',
    'wbc_avg', 'age'  # Numeric features
]

# Step 1: Convert the flattened numpy arrays back to pandas DataFrames
# Ensure all columns, including 'aki_stage', are preserved in the order
X_train_df = pd.DataFrame(X_train_flattened, columns=feature_names_with_id[1:])  # Skip 'icustay_id'
X_test_df = pd.DataFrame(X_test_flattened, columns=feature_names_with_id[1:])    # Skip 'icustay_id'
X_validation_df = pd.DataFrame(X_validation_flattened, columns=feature_names_with_id[1:])  # Skip 'icustay_id'

# Step 2: Merge the DataFrames back with the 'icustay_id' column and the 'aki_stage' column
# Assuming you have the 'icustay_id' and 'aki_stage' from your y variables, merge them back
final_dataset_train = pd.concat([pd.DataFrame(X_train_flattened, columns=feature_names_with_id[1:]), pd.DataFrame(y_train, columns=['aki_stage'])], axis=1)
final_dataset_test = pd.concat([pd.DataFrame(X_test_flattened, columns=feature_names_with_id[1:]), pd.DataFrame(y_test, columns=['aki_stage'])], axis=1)
final_dataset_validation = pd.concat([pd.DataFrame(X_validation_flattened, columns=feature_names_with_id[1:]), pd.DataFrame(y_validation, columns=['aki_stage'])], axis=1)

# Combine the DataFrames if needed
final_dataset = pd.concat([final_dataset_train, final_dataset_test, final_dataset_validation], ignore_index=True)

# Save the final dataset to CSV, preserving the 'aki_stage' column
final_dataset.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/final_dataset-raw_flat.csv', index=False)

# Step 3: Use the `aki_stage` column from the dataset as y variables for further processing

# Extract the labels from the correct 'aki_stage' column
y_train = final_dataset_train['aki_stage'].values
y_test = final_dataset_test['aki_stage'].values
y_validation = final_dataset_validation['aki_stage'].values

# Remove 'aki_stage' from feature datasets
X_train_final = final_dataset_train.drop(['aki_stage'], axis=1)
X_test_final = final_dataset_test.drop(['aki_stage'], axis=1)
X_validation_final = final_dataset_validation.drop(['aki_stage'], axis=1)

(X_train_final.shape, y_train.shape, X_test_final.shape, y_test.shape, X_validation_final.shape, y_validation.shape)

# %%
print(list(train.columns))
# Out:
# ['icustay_id', 'aki_stage', 'aniongap_avg', 'bicarbonate_avg', 'bun_avg', 'chloride_avg', 'creat', 'diasbp_mean', 'glucose_avg', 'heartrate_mean', 'hematocrit_avg', 'hemoglobin_avg', 'potassium_avg', 'resprate_mean', 'sodium_avg', 'spo2_mean', 'sysbp_mean', 'uo_rt_12hr', 'uo_rt_24hr', 'uo_rt_6hr', 'wbc_avg', 'sedative', 'vasopressor', 'vent', 'age', 'F', 'M', 'asian', 'black', 'hispanic', 'native', 'other', 'unknown', 'white']

# %%
print(list(X_train.columns))
# Out:
# ['F', 'M', 'asian', 'black', 'hispanic', 'native', 'other', 'unknown', 'white', 'sedative', 'vasopressor', 'vent', 'aniongap_avg', 'bicarbonate_avg', 'bun_avg', 'chloride_avg', 'creat', 'diasbp_mean', 'glucose_avg', 'heartrate_mean', 'hematocrit_avg', 'hemoglobin_avg', 'potassium_avg', 'resprate_mean', 'sodium_avg', 'spo2_mean', 'sysbp_mean', 'uo_rt_12hr', 'uo_rt_24hr', 'uo_rt_6hr', 'wbc_avg', 'age']

# %%
# Explicitly identify the index of the 'aki_stage' column
aki_stage_index = list(train.columns).index('aki_stage')
print(aki_stage_index)
# Out:
# 1

# %%
print(list(X_train.shape))
# Out:
# [37802, 32]

# %%
print(y_test)
# Out:
#      aki_stage
# 0          0.0
# 1          3.0
# 2          0.0
# 3          0.0
# 4          0.0
# ...        ...
# 4719       0.0
# 4720       2.0
# 4721       0.0
# 4722       0.0
# 4723       0.0
#
# [4724 rows x 1 columns]

# %%
# Save the X and y variables to CSV files
X_train.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_train-raw.csv', index=False)
X_test.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_test-raw.csv', index=False)
X_validation.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_validation-raw.csv', index=False)

y_train.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/y_train-raw.csv', index=False)
y_test.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/y_test-raw.csv', index=False)
y_validation.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/y_validation-raw.csv', index=False)

print("X and y variables saved to CSV files.")

# Load the variables from the CSV files for modeling
X_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_train-raw.csv')
X_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_test-raw.csv')
X_validation = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_validation-raw.csv')

y_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/y_train-raw.csv')
y_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/y_test-raw.csv')
y_validation = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/y_validation-raw.csv')

print("X and y variables loaded from CSV files.")

# Check that the loaded data matches the original
print(f"Loaded X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"Loaded X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
print(f"Loaded X_validation shape: {X_validation.shape}, y_validation shape: {y_validation.shape}")

# %%
# Save the X and y variables to CSV files
X_train.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_train-final.csv', index=False)
X_test.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_test-final.csv', index=False)
X_validation.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_validation-final.csv', index=False)

y_train.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/y_train-final.csv', index=False)
y_test.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/y_test-final.csv', index=False)
y_validation.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/y_validation-final.csv', index=False)

print("X and y variables saved to CSV files.")

# Load the variables from the CSV files for modeling
X_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_train-final.csv')
X_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_test-final.csv')
X_validation = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_validation-final.csv')

y_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/y_train-final.csv')
y_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/y_test-final.csv')
y_validation = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/y_validation-final.csv')

print("X and y variables loaded from CSV files.")

# Check that the loaded data matches the original
print(f"Loaded X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"Loaded X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
print(f"Loaded X_validation shape: {X_validation.shape}, y_validation shape: {y_validation.shape}")
# Out:
# X and y variables saved to CSV files.
# X and y variables loaded from CSV files.
# Loaded X_train shape: (37802, 32), y_train shape: (37802, 1)
# Loaded X_test shape: (4724, 32), y_test shape: (4724, 1)
# Loaded X_validation shape: (4724, 32), y_validation shape: (4724, 1)

# %%
# Save the X and y variables to CSV files
X_train.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_train-ord.csv', index=False)
X_test.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_test-ord.csv', index=False)
X_validation.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_validation-ord.csv', index=False)

y_train.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/y_train-ord.csv', index=False)
y_test.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/y_test-ord.csv', index=False)
y_validation.to_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/y_validation-ord.csv', index=False)

print("X and y variables saved to CSV files.")

# Load the variables from the CSV files for modeling
X_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_train-ord.csv')
X_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_test-ord.csv')
X_validation = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/X_validation-ord.csv')

y_train = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/y_train-ord.csv')
y_test = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/y_test-ord.csv')
y_validation = pd.read_csv('/content/drive/MyDrive/Colab Notebooks/AKI/final/input_data/y_validation-ord.csv')

print("X and y variables loaded from CSV files.")

# Check that the loaded data matches the original
print(f"Loaded X_train shape: {X_train.shape}, y_train shape: {y_train.shape}")
print(f"Loaded X_test shape: {X_test.shape}, y_test shape: {y_test.shape}")
print(f"Loaded X_validation shape: {X_validation.shape}, y_validation shape: {y_validation.shape}")
# Out:
# X and y variables saved to CSV files.
# X and y variables loaded from CSV files.
# Loaded X_train shape: (37802, 32), y_train shape: (37802, 1)
# Loaded X_test shape: (4724, 32), y_test shape: (4724, 1)
# Loaded X_validation shape: (4724, 32), y_validation shape: (4724, 1)
